# %% [markdown]
# # Installation and Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import math
import pandas as pd
import scanpy as sc
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, silhouette_score
import time
import tracemalloc
from tensorflow.keras.regularizers import l2

# %%
import scvi
# Out:
# Global seed set to 0

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# scanpy==1.9.6 anndata==0.9.2 umap==0.5.7 numpy==1.19.5 scipy==1.10.1 pandas==1.4.4 scikit-learn==1.3.2 statsmodels==0.14.1 igraph==0.11.8 louvain==0.8.2 pynndescent==0.5.13

# %% [markdown]
# # Defined Methods

# %% [markdown]
# ## Data Preprocessing

# %%
def data_init(path):
    print("\n==========================  Data Initialization  =================================\n")
    data = pd.read_csv(path, index_col=0).astype('float64')
    clusters = data.columns
    clusters = [int(x) for x in [float(x) for x in clusters]]
    adata = sc.AnnData(X=(data.values.T))
    adata.var_names = data.index
    adata.obs_names = [f"cell-{i}" for i in range(1, len(clusters) + 1)]
    adata.obs["cluster"] = clusters
    print("Loaded Dataset Structure: ")
    print((pd.DataFrame(adata.X, index=adata.obs.index, columns=adata.var.index)).iloc[:10, :10])
    print(adata)
    print(f'Total Clusters: \n{np.unique(adata.obs["cluster"])}')
    print(f'Clusters: \n{adata.obs["cluster"]}')
    sc.pp.pca(adata, n_comps=50) 
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)
    print("Existing Cluster")
    sc.pl.umap(adata, color='cluster')
    return adata

# %%
def data_processing(adata):
  print("\n==========================  Data Processing  =================================\n")
  sc.pp.filter_cells(adata, min_genes=200)
  sc.pp.filter_genes(adata, min_cells=3)
  sc.pp.normalize_per_cell(adata)
  sc.pp.log1p(adata, copy=True)
  return adata

# %% [markdown]
# ## Denoising

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import scanpy as sc
import numpy as np

def Denoise(adata):
    
    # Step 1: Load and preprocess data
    X = adata.X  # Assuming adata.X is in sparse format
    X = X.toarray() if hasattr(X, "toarray") else X  # Convert to dense if sparse
    
    # Normalize and scale data
    X = sc.pp.log1p(X, copy=True)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    # Step 2: Add sparse noise to mimic biological dropout
    def add_sparse_noise(data, dropout_rate=0.1):
        """
        Adds sparse dropout noise to mimic missing data in scRNA-seq.
        """
        noisy_data = data.copy()
        mask = np.random.binomial(1, dropout_rate, size=data.shape)  # Create dropout mask
        noisy_data[mask == 1] = 0  # Set selected values to zero
        return noisy_data
    
    X_noisy = add_sparse_noise(X)
    
    # Step 3: Define sparse-aware denoising autoencoder
    input_dim = X.shape[1]
    
    # Encoder
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(512, activation='relu')(input_layer)
    encoded = BatchNormalization()(encoded)
    encoded = Dropout(0.2)(encoded)
    latent_space = Dense(128, activation='relu')(encoded)
    
    # Decoder
    decoded = Dense(512, activation='relu')(latent_space)
    decoded = BatchNormalization()(decoded)
    decoded = Dropout(0.2)(decoded)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    # Autoencoder model
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    
    # Custom sparse-aware loss
    def sparse_mse(y_true, y_pred):
        """
        Custom loss to preserve zeros and penalize large changes to nonzero values.
        """
        mask = tf.cast(tf.equal(y_true, 0.0), tf.float32)  # Mask for zeros in original data
        nonzero_loss = tf.reduce_mean(tf.square((1 - mask) * (y_true - y_pred)))  # Penalize changes to nonzeros
        zero_loss = tf.reduce_mean(tf.square(mask * y_pred))  # Penalize predicted values where true value is zero
        return nonzero_loss + 0.1 * zero_loss  # Combine losses with weight for zero preservation
    
    # Compile the model
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                        loss=sparse_mse,
                        metrics=['mae'])
    
    # Step 4: Train the model
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
    X_noisy_train, X_noisy_val = train_test_split(X_noisy, test_size=0.2, random_state=42)
    
    history = autoencoder.fit(
        X_noisy_train, X_train,
        validation_data=(X_noisy_val, X_val),
        epochs=300,
        batch_size=256,
        shuffle=True,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
        ]
    )
    
    # Step 5: Denoise the data
    X_denoised = autoencoder.predict(X_noisy)
    
    # Save the denoised output
    adata.X = scaler.inverse_transform(X_denoised)  # Inverse scaling
    return adata

# %% [markdown]
# ## Clustering

# %%
def cluster_with_louvain(adata, epochs, resolution=2.5):
  print("\n========================== Clustering With Louvain =================================\n")
  # if "X_pca" not in adata.obsm and "neighbors" not in adata.uns:
  sc.pp.pca(adata)
  sc.pp.neighbors(adata)
  sil_scores = []

  for i in range(0, epochs):
    sc.tl.louvain(adata, resolution)

    print(f"\nClustering epoch {i+1} ------------------")
    ari = adjusted_rand_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Adjusted Rand Index (ARI): {ari:.4f}")

    nmi = normalized_mutual_info_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Normalized Mutual Information (NMI): {nmi:.4f}")

    X = adata.obsm["X_pca"]
    sil_score = silhouette_score(X, adata.obs['louvain'])
    sil_scores.append(sil_score)
    print(f"Silhouette Score: {sil_score:.4f}\n")

      
  sc.tl.umap(adata)
  sc.pl.umap(adata, color='louvain')
  return sil_scores

# %% [markdown]
# ## Identify Marker Gene

# %% [markdown]
# ### CellTICS

# %%
# Define fphi - High markers
def fphi(x):

    # Step 1: Normalized by max value (x + 1) / (max(x) + 1)
    normalized = (x + 1).div(x.max(axis=1) + 1, axis=0)

    # Step 2: Suppression factor (zt)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)

    # Step 3: phi values after applying suppression factor
    zp = normalized.mul(zt, axis=0)

    return zp

# Define frho - Low markers
def frho(x):
    # Step 1: Normalized by min value (1 / (x + 1)) * (min(x) + 1)
    normalized = (1 / (x + 1)).mul(x.min(axis=1) + 1, axis=0)

    # Step 2: Enhancement factor (zt)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)

    # Step 3: rho values after applying enhancement factor
    zp = normalized.mul(zt, axis=0)

    return zp



# thr1 -> high marker quantile | thr2 -> Low marker quantile
def CellTICS_marker_genes(adata, thr1=0.95, thr2=0.9):
  print("\n====================== Identify Marker Gene With CellTICS ============================\n")
  print("Expression Values of Genes: \n")
  expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
  louvain_labels = pd.Series(adata.obs['louvain'].values, index=adata.obs_names)
  print(expr_data.iloc[:10, :10])
  print(adata)

  print("\nAverage the cell expr data according to the clusters:\n")
  avg_expr_data = expr_data.T.groupby(louvain_labels).mean().T
  print(avg_expr_data.iloc[:10, :])

  phi = fphi(avg_expr_data)
  rho = frho(avg_expr_data)


  gnm = phi.index.values 
  ctpnm = phi.columns.values


  phi = np.array(phi)
  rho = np.array(rho)


  nummkg1 = math.ceil((1 - thr1) * phi.shape[0]) 
  nummkg2 = math.ceil((1 - thr2) * phi.shape[0]) 


  alpha = [] 
  beta = []
  for i in range(0, phi.shape[1]):
      alpha.append(np.quantile(phi[:, i], thr1))
      beta.append(np.quantile(rho[:, i], thr2))



  mkh = [] 
  mkl = [] 
  for i in range(0, phi.shape[1]):
      high_markers = gnm[phi[:, i] >= alpha[i]][0:nummkg1]
      low_markers = gnm[rho[:, i] >= beta[i]][0:nummkg2]
      mkh = np.concatenate([mkh, high_markers], axis=0) if len(mkh) > 0 else high_markers
      mkl = np.concatenate([mkl, low_markers], axis=0) if len(mkl) > 0 else low_markers


  mkh = mkh.reshape(nummkg1, phi.shape[1])
  mkl = mkl.reshape(nummkg2, rho.shape[1])
  mkh = pd.DataFrame(mkh, columns=ctpnm)
  mkl = pd.DataFrame(mkl, columns=ctpnm)

  print("\nHigh Marker Genes for each cluster/type: \n")
  print(mkh.iloc[:10, :])

  print("\nLow Marker Genes for each cluster/type: \n")
  print(mkl.iloc[:10, :])

  return mkh, mkl

# %%
# getting list of all high and low marker genes
def get_unique_marker_genes(high_markers):
  unique_high_markers = high_markers
  unique_high_markers = pd.unique(unique_high_markers.values.ravel()).tolist()
  print(f"\nTotal Unique High Marker Gene for all together {len(unique_high_markers)}: ")
  return unique_high_markers

# %% [markdown]
# ## Calculate Importance

# %%
def calculate_importance(silhouette_scores):
    avg_scores = {k: sum(v) / len(v) for k, v in silhouette_scores.items()}
    
    total = sum(avg_scores.values())
    return {k: v / total for k, v in avg_scores.items()}

# %% [markdown]
# ## Unified Marker Genes (Weight Based)

# %%
from collections import defaultdict

def score_marker_genes(celltics_genes, smash_genes, cosg_genes, importance, p=1.0):
    
    gene_weights = defaultdict(float)
    
    for gene in celltics_genes:
        gene_weights[gene] += importance['celltics']
        
    for gene in smash_genes:
        gene_weights[gene] += importance['smash']
        
    for gene in cosg_genes:
        gene_weights[gene] += importance['cosg']
    
    selected_genes = sorted(gene_weights.items(), key=lambda x: x[1], reverse=True) # selecting genes with highest weight

    print(f'total genes: {len(selected_genes)}')
    
    top_n = int(len(selected_genes) * p)

    print(f'selected genes: {top_n}')
    
    return [gene for gene, weight in selected_genes[:top_n]]

# %% [markdown]
# # Implementations____________

# %%
dataset_path = "data/Goolam.csv"

adata = data_init(dataset_path)

adata = data_processing(adata)

adata = Denoise(adata)
# Out:
# ==========================  Data Initialization  =================================
#
# Loaded Dataset Structure:
#          ENSMUSG00000000001  ENSMUSG00000000003  ENSMUSG00000000028  ENSMUSG00000000031  ENSMUSG00000000037  ENSMUSG00000000049  ENSMUSG00000000056  ENSMUSG00000000058  ENSMUSG00000000078  ENSMUSG00000000085
# cell-1                165.0                 0.0               722.0                 0.0                58.0                 0.0                12.0                 0.0                 0.0                10.0
# cell-2                 79.0                 0.0               547.0                 0.0                33.0                 0.0                 3.0                 0.0                 0.0                 1.0
# cell-3                124.0                 0.0               481.0                 0.0                22.0                 0.0                 7.0                 0.0                 0.0                31.0
# cell-4                 41.0                 0.0               219.0                 0.0                34.0                 0.0                 9.0                 0.0                 0.0                38.0
# cell-5                107.0                 0.0               808.0                 0.0                68.0                 0.0                20.0                 0.0                 0.0                64.0
# cell-6                167.0                 0.0               483.0                 0.0                27.0                 0.0                11.0                 2.0                 1.0                10.0
# cell-7                 84.0                 0.0               221.0                 0.0                 0.0                 0.0                 3.0                 0.0                 0.0                 5.0
# cell-8                 70.0                 0.0               280.0                 0.0                 9.0                 0.0                 4.0                 0.0                 0.0                 1.0
# cell-9                 28.0                 0.0               158.0                 0.0                 5.0                 0.0                 2.0                 0.0                 0.0                 5.0
# cell-10                42.0                 0.0               222.0                 0.0                10.0                 0.0                 0.0                 0.0                 0.0                 5.0
# AnnData object with n_obs × n_vars = 124 × 41480
#     obs: 'cluster'
# Total Clusters:
# [0 1 2 3 4]
# Clusters:
# cell-1      0
# cell-2      0
# cell-3      0
# cell-4      0
# cell-5      0
#            ..
# cell-120    1
# cell-121    1
# cell-122    1
# cell-123    1
# cell-124    1
# Name: cluster, Length: 124, dtype: int64
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:05)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)
# Existing Cluster
# ==========================  Data Processing  =================================
#
# filtered out 17391 genes that are detected in less than 3 cells
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# Epoch 1/300
# 1/1 [==============================] - 2s 2s/step - loss: 1.2838 - mae: 0.9033 - val_loss: 1.1286 - val_mae: 0.8508
# Epoch 2/300
# 1/1 [==============================] - 0s 272ms/step - loss: 1.2823 - mae: 0.9028 - val_loss: 1.1283 - val_mae: 0.8507
# Epoch 3/300
# 1/1 [==============================] - 0s 217ms/step - loss: 1.2806 - mae: 0.9023 - val_loss: 1.1280 - val_mae: 0.8506
# Epoch 4/300
# 1/1 [==============================] - 0s 213ms/step - loss: 1.2787 - mae: 0.9017 - val_loss: 1.1276 - val_mae: 0.8504
# Epoch 5/300
# 1/1 [==============================] - 0s 219ms/step - loss: 1.2770 - mae: 0.9011 - val_loss: 1.1269 - val_mae: 0.8502
# Epoch 6/300
# 1/1 [==============================] - 0s 215ms/step - loss: 1.2749 - mae: 0.9004 - val_loss: 1.1261 - val_mae: 0.8499
# Epoch 7/300
# 1/1 [==============================] - 0s 207ms/step - loss: 1.2726 - mae: 0.8996 - val_loss: 1.1251 - val_mae: 0.8495
# Epoch 8/300
# 1/1 [==============================] - 0s 239ms/step - loss: 1.2702 - mae: 0.8988 - val_loss: 1.1239 - val_mae: 0.8490
# Epoch 9/300
# 1/1 [==============================] - 0s 220ms/step - loss: 1.2679 - mae: 0.8980 - val_loss: 1.1225 - val_mae: 0.8485
# Epoch 10/300
# 1/1 [==============================] - 0s 216ms/step - loss: 1.2654 - mae: 0.8971 - val_loss: 1.1209 - val_mae: 0.8479
# Epoch 11/300
# 1/1 [==============================] - 0s 217ms/step - loss: 1
- val_loss: 0.9547 - val_mae: 0.7540
# Epoch 294/300
# 1/1 [==============================] - 0s 203ms/step - loss: 0.9581 - mae: 0.7473 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 295/300
# 1/1 [==============================] - 0s 215ms/step - loss: 0.9560 - mae: 0.7465 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 296/300
# 1/1 [==============================] - 0s 221ms/step - loss: 0.9549 - mae: 0.7455 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 297/300
# 1/1 [==============================] - 0s 215ms/step - loss: 0.9549 - mae: 0.7456 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 298/300
# 1/1 [==============================] - 0s 216ms/step - loss: 0.9560 - mae: 0.7461 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 299/300
# 1/1 [==============================] - 0s 214ms/step - loss: 0.9553 - mae: 0.7458 - val_loss: 0.9547 - val_mae: 0.7540
# Epoch 300/300
# 1/1 [==============================] - 0s 210ms/step - loss: 0.9559 - mae: 0.7460 - val_loss: 0.9547 - val_mae: 0.7540

# %% [markdown]
# # CellTICS Marker Genes

# %%
cluster_with_louvain(adata, epochs=1, resolution=0.5)
t=time.process_time()
tracemalloc.start()

high_markers, low_markers = CellTICS_marker_genes(adata, thr1=0.99, thr2= 0.95)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()


high_markers = get_unique_marker_genes(high_markers)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 5 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.5439
# Normalized Mutual Information (NMI): 0.7210
# Silhouette Score: 0.4520
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:00)
# ====================== Identify Marker Gene With CellTICS ============================
#
# Expression Values of Genes:
#
#                       cell-1    cell-2    cell-3    cell-4    cell-5    cell-6    cell-7    cell-8    cell-9   cell-10
# ENSMUSG00000000001  4.781153  4.795704  4.771677  4.748194  4.751934  4.795839  4.595502  4.594935  4.524357  4.572349
# ENSMUSG00000000028  6.062008  6.062539  6.062528  6.062543  6.061872  6.062506  5.901573  5.836163  5.770967  5.696440
# ENSMUSG00000000037  3.164767  3.165713  3.165692  3.165727  3.164526  3.165668  2.078614  2.052725  1.980681  1.995936
# ENSMUSG00000000049  0.193436  0.189595  0.185775  0.184744  0.190193  0.183640  0.146308  0.148728  0.149695  0.146850
# ENSMUSG00000000056  2.229177  2.229762  2.229750  2.229769  2.229033  2.229740  1.223104  1.221658  1.218379  1.241756
# ENSMUSG00000000058  0.855422  0.835223  0.833856  0.831915  0.858351  0.857464  1.023420  0.988303  0.986847  1.188996
# ENSMUSG00000000078  1.866155  1.869464  1.869414  1.869524  1.865767  1.869383  0.812906  0.796802  0.800214  0.821678
# ENSMUSG00000000085  3.196315  3.197767  3.197744  3.197789  3.196113  3.197725  2.164436  2.142784  2.181091  2.220216
# ENSMUSG00000000088  5.366500  5.361462  5.349707  5.284795  5.331300  5.350253  5.551920  5.506080  5.452874  5.501189
# ENSMUSG00000000093  0.224362  0.208130  0.210215  0.214486  0.234819  0.217245  0.225035  0.255597  0.239955  0.263414
# AnnData object with n_obs × n_vars = 124 × 24089
#     obs: 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'pca', 'neighbors', 'umap', 'louvain', 'louvain_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities
# 5  ENSMUSG00000002871  ENSMUSG00000002881  ENSMUSG00000002997  ENSMUSG00000003031  ENSMUSG00000003051
# 6  ENSMUSG00000003198  ENSMUSG00000003352  ENSMUSG00000003418  ENSMUSG00000003518  ENSMUSG00000003528
# 7  ENSMUSG00000003541  ENSMUSG00000003559  ENSMUSG00000003847  ENSMUSG00000003849  ENSMUSG00000003955
# 8  ENSMUSG00000004085  ENSMUSG00000004098  ENSMUSG00000004267  ENSMUSG00000004371  ENSMUSG00000004451
# 9  ENSMUSG00000004500  ENSMUSG00000004633  ENSMUSG00000004843  ENSMUSG00000004902  ENSMUSG00000004988
# Memory Usage: 26.53 Mb
# Required Time: 0.125 sec
#
# Total Unique High Marker Gene for all together 809:

# %% [markdown]
# # Cluster Reconstructed Dataset (CellTICS)

# %%
expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
expr_data = expr_data.loc[high_markers]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 124 × 809
#     obs: 'cluster'

# %%
# rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

# %%
cellTICS_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.5)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 5 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.5439
# Normalized Mutual Information (NMI): 0.7210
# Silhouette Score: 0.5704
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:00)

# %% [markdown]
# # Smash Marker Genes

# %%
import os
import smashpy

smash = smashpy.smashpy()

if np.any(np.isnan(adata.X)):
    adata.X = np.nan_to_num(adata.X)

if not os.path.exists('Figures'):
    os.makedirs('Figures')

smash.DNN(adata, group_by='louvain')
# Out:
#  * Initialising ...
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\smashpy.py:72: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 32)                770880
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 85
# =================================================================
# Total params: 771,685
# Trainable params: 771,589
# Non-trainable params: 96
# _________________________________________________________________
# None
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6974 - accuracy: 0.3535 - auc: 0.6055 - precision: 0.6000 - recall: 0.0303 - val_loss: 1.7291 - val_accuracy: 0.4400 - val_auc: 0.6586 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.72907, saving model to weights\best_model_louvain.h5
# Epoch 2/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3578 - accuracy: 0.4747 - auc: 0.7673 - precision: 0.8571 - recall: 0.0606 - val_loss: 1.7261 - val_accuracy: 0.4400 - val_auc: 0.6618 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 1.72907 to 1.72611, saving model to weights\best_model_louvain.h5
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3766 - accuracy: 0.4040 - auc: 0.7652 - precision: 0.8750 - recall: 0.0707 - val_loss: 1.7303 - val_accuracy: 0.4400 - val_auc: 0.6468 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 1.72611
# Epoch 4/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3146 - accuracy: 0.5354 - auc: 0.7962 - precision: 0.9091 - recall: 0.1010 - val_loss: 1.7332 - val_accuracy: 0.3600 - val_auc: 0.6526 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 1.72611
# Epoch 5/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3044 - accuracy: 0.4848 - auc: 0.7978 - precision: 0.8889 - recall: 0.0808 - val_loss: 1.7384 - val_accuracy: 0.2400 - val_auc: 0.6324 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 1.72611
# Epoch 6/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2946 - accuracy: 0.5051 - auc: 0.8051 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.7217 - val_accuracy: 0.2400 - val_auc: 0.6348 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00006: val_loss improved from 1.72611 to 1.72174, saving model to weights\best_model_louvain.h5
# Epoch 7/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2879 - accuracy: 0.5354 - auc: 0.8142 - precision: 0.9091 - recall: 0.1010 - val_loss: 1.7124 - val_accuracy: 0.4000 - val_auc: 0.6494 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00007: val_loss improved from 1.72174 to 1.71243, saving model to weights\best_model_louvain.h5
# Epoch 8/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2627 - accuracy: 0.5253 - auc: 0.8278 - precision: 1.0000 - recall: 0.1010 - val_loss: 1.7073 - val_accuracy: 0.4400 - val_auc: 0.6642 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00008: val_loss improved from 1.71243 to 1.70728, saving model to weights\best_model_louvain.h5
# Epoch 9/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2558 - accuracy: 0.5253 - auc: 0.8301 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.7046 - val_accuracy: 0.3200 - val_auc: 0.6550 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00009: val_loss improved from 1.70728 to 1.70457, saving model to weights\best_model_louvain.h5
# Epoch 10/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2346 - accuracy: 0.5960 - auc: 0.8424 - precision: 0.8750 - recall: 0.0707 - val_loss: 1.7003 - val_accuracy: 0.3600 - val_auc: 0.6476 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00010: val_loss improved from 1.70457 to 1.70027, saving model to weights\best_model_louvain.h5
# Epoch 11/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2622 - accuracy: 0.5354 - auc: 0.8275 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6942 - val_accuracy: 0.3600 - val_auc: 0.6686 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00011: val_loss improved from 1.70027 to 1.69420, saving model to weights\best_model_louvain.h5
# Epoch 12/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2226 - accuracy: 0.5455 - auc: 0.8453 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.6875 - val_accuracy: 0.4400 - val_auc: 0.6636 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00012: val_loss improved from 1.69420 to 1.68749, saving model to weights\best_model_louvain.h5
# Epoch 13/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2016 - accuracy: 0.5960 - auc: 0.8642 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6808 - val_accuracy: 0.3600 - val_auc: 0.6550 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00013: val_loss improved from 1.68749 to 1.68083, saving model to weights\best_model_louvain.h5
# Epoch 14/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2100 - accuracy: 0.5859 - auc: 0.8588 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6738 - val_accuracy: 0.2000 - val_auc: 0.6312 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00014: val_loss improved from 1.68083 to 1.67384, saving model to weights\best_model_louvain.h5
# Epoch 15/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2161 - accuracy: 0.6061 - auc: 0.8487 - precision: 1.0000 - recall: 0.1111 - val_loss: 1.6673 - val_accuracy: 0.1600 - val_auc: 0.6318 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00015: val_loss improved from 1.67384 to 1.66731, saving model to weights\best_model_louvain.h5
# Epoch 16/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.1690 - accuracy: 0.6162 - auc: 0.8803 - precision: 1.0000 - recall: 0.1010 - val_loss: 1.6621 - val_accuracy: 0.1200 - val_auc: 0.6166 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00016: val_loss improved from 1.66731 to 1.66212, saving model to weights\best_model_louvain.h5
# Epoch 17/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.1518 - accuracy: 0.6667 - auc: 0.8885 - precision: 1.0000 - recall: 0.1111 - val_loss: 1.6564 - val_accuracy: 0.1200 - val_auc: 0.6100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00017: val_loss improved from 1.66212 to 1.65639, saving model to weights\best_model_louvain.h5
# Epoch 18/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.1643 - accuracy: 0.6465 - auc: 0.8780 - precision: 0.9167 - recall: 0.1111 - val_loss: 1.6509 - val_accuracy: 0.1200 - val_auc: 0.6082 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00018: val_loss improved from 1.65639 to 1.65089, saving model to weights\best_model_louvain.h5
# Epoch 19/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.1437 - accuracy: 0.6566 - auc: 0.8854 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6446 - val_accuracy: 0.1200 - val_auc: 0.6204 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00019: val_loss improved from 1.65089 to 1.64463, saving model to weights\best_model_louvain.h5
# Epoch 20/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.1631 - accuracy: 0.6263 - auc: 0.8861 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6389 - val_accuracy: 0.1600 - val_auc: 0.6214 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00020: val_loss improved from 1.64463 to 1.63893, saving model to weights\best_model_louvain.h5
# Epoch 21/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1289 - accuracy: 0.6970 - auc: 0.9153 - precision: 0.8571 - recall: 0.0606 - val_loss: 1.6360 - val_accuracy: 0.1600 - val_auc: 0.6148 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00021: val_loss improved from 1.63893 to 1.63599, saving model to weights\best_model_louvain.h5
# Epoch 22/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.1891 - accuracy: 0.6263 - auc: 0.8785 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6340 - val_accuracy: 0.1200 - val_auc: 0.6116 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00022: val_loss improved from 1.63599 to 1.63402, saving model to weights\best_model_louvain.h5
# Epoch 23/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.1317 - accuracy: 0.6263 - auc: 0.9132 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.6336 - val_accuracy: 0.1200 - val_auc: 0.6082 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00023: val_loss improved from 1.63402 to 1.63356, saving model to weights\best_model_louvain.h5
# Epoch 24/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.1259 - accuracy: 0.6667 - auc: 0.9103 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6332 - val_accuracy: 0.1200 - val_auc: 0.6162 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00024: val_loss improved from 1.63356 to 1.63319, saving model to weights\best_model_louvain.h5
# Epoch 25/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1381 - accuracy: 0.7273 - auc: 0.9083 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.6341 - val_accuracy: 0.1200 - val_auc: 0.6148 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00025: val_loss did not improve from 1.63319
# Epoch 26/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.1439 - accuracy: 0.6364 - auc: 0.9066 - precision: 1.0000 - recall: 0.0505 - val_loss: 1.6347 - val_accuracy: 0.1200 - val_auc: 0.6054 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00026: val_loss did not improve from 1.63319
# Epoch 27/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.1102 - accuracy: 0.7172 - auc: 0.9169 - precision: 0.9167 - recall: 0.1111 - val_loss: 1.6351 - val_accuracy: 0.1200 - val_auc: 0.6012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00027: val_loss did not improve from 1.63319
# Epoch 28/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.1311 - accuracy: 0.6970 - auc: 0.9214 - precision: 1.0000 - recall: 0.0606 - val_loss: 1.6349 - val_accuracy: 0.1200 - val_auc: 0.5996 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00028: val_loss did not improve from 1.63319
# Epoch 29/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0953 - accuracy: 0.7778 - auc: 0.9318 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6331 - val_accuracy: 0.1200 - val_auc: 0.6030 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00029: val_loss improved from 1.63319 to 1.63310, saving model to weights\best_model_louvain.h5
# Epoch 30/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0754 - accuracy: 0.7273 - auc: 0.9423 - precision: 1.0000 - recall: 0.1010 - val_loss: 1.6308 - val_accuracy: 0.1200 - val_auc: 0.6028 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00030: val_loss improved from 1.63310 to 1.63075, saving model to weights\best_model_louvain.h5
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0946 - accuracy: 0.6869 - auc: 0.9275 - precision: 1.0000 - recall: 0.0606 - val_loss: 1.6285 - val_accuracy: 0.1200 - val_auc: 0.6056 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00031: val_loss improved from 1.63075 to 1.62848, saving model to weights\best_model_louvain.h5
# Epoch 32/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0691 - accuracy: 0.7879 - auc: 0.9565 - precision: 1.0000 - recall: 0.0606 - val_loss: 1.6263 - val_accuracy: 0.1200 - val_auc: 0.6108 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00032: val_loss improved from 1.62848 to 1.62628, saving model to weights\best_model_louvain.h5
# Epoch 33/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0972 - accuracy: 0.7475 - auc: 0.9323 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.6241 - val_accuracy: 0.1200 - val_auc: 0.6236 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00033: val_loss improved from 1.62628 to 1.62414, saving model to weights\best_model_louvain.h5
# Epoch 34/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.1053 - accuracy: 0.6970 - auc: 0.9246 - precision: 1.0000 - recall: 0.0505 - val_loss: 1.6226 - val_accuracy: 0.1200 - val_auc: 0.6484 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00034: val_loss improved from 1.62414 to 1.62256, saving model to weights\best_model_louvain.h5
# Epoch 35/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0710 - accuracy: 0.7576 - auc: 0.9401 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.6219 - val_accuracy: 0.1200 - val_auc: 0.6550 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00035: val_loss improved from 1.62256 to 1.62187, saving model to weights\best_model_louvain.h5
# Epoch 36/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0910 - accuracy: 0.7576 - auc: 0.9360 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6219 - val_accuracy: 0.1200 - val_auc: 0.6614 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00036: val_loss did not improve from 1.62187
# Epoch 37/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0919 - accuracy: 0.7677 - auc: 0.9446 - precision: 1.0000 - recall: 0.1111 - val_loss: 1.6225 - val_accuracy: 0.1200 - val_auc: 0.6602 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00037: val_loss did not improve from 1.62187
# Epoch 38/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0886 - accuracy: 0.7475 - auc: 0.9313 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6225 - val_accuracy: 0.1200 - val_auc: 0.6582 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00038: val_loss did not improve from 1.62187
# Epoch 39/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0583 - accuracy: 0.7475 - auc: 0.9482 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.6210 - val_accuracy: 0.1600 - val_auc: 0.6606 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00039: val_loss improved from 1.62187 to 1.62097, saving model to weights\best_model_louvain.h5
# Epoch 40/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0887 - accuracy: 0.7677 - auc: 0.9331 - precision: 1.0000 - recall: 0.0505 - val_loss: 1.6186 - val_accuracy: 0.2400 - val_auc: 0.6688 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00040: val_loss improved from 1.62097 to 1.61858, saving model to weights\best_model_louvain.h5
# Epoch 41/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0427 - accuracy: 0.8283 - auc: 0.9635 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.6159 - val_accuracy: 0.2800 - val_auc: 0.6750 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00041: val_loss improved from 1.61858 to 1.61593, saving model to weights\best_model_louvain.h5
# Epoch 42/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0718 - accuracy: 0.7172 - auc: 0.9382 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.6138 - val_accuracy: 0.3600 - val_auc: 0.6850 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00042: val_loss improved from 1.61593 to 1.61382, saving model to weights\best_model_louvain.h5
# Epoch 43/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0526 - accuracy: 0.7778 - auc: 0.9633 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.6119 - val_accuracy: 0.3600 - val_auc: 0.6840 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00043: val_loss improved from 1.61382 to 1.61186, saving model to weights\best_model_louvain.h5
# Epoch 44/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0470 - accuracy: 0.7980 - auc: 0.9535 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6098 - val_accuracy: 0.3600 - val_auc: 0.6864 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00044: val_loss improved from 1.61186 to 1.60976, saving model to weights\best_model_louvain.h5
# Epoch 45/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0139 - accuracy: 0.7879 - auc: 0.9647 - precision: 1.0000 - recall: 0.1010 - val_loss: 1.6071 - val_accuracy: 0.3600 - val_auc: 0.6898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00045: val_loss improved from 1.60976 to 1.60707, saving model to weights\best_model_louvain.h5
# Epoch 46/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0601 - accuracy: 0.7374 - auc: 0.9362 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.6038 - val_accuracy: 0.4000 - val_auc: 0.6966 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00046: val_loss improved from 1.60707 to 1.60380, saving model to weights\best_model_louvain.h5
# Epoch 47/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0311 - accuracy: 0.7980 - auc: 0.9657 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.6008 - val_accuracy: 0.4000 - val_auc: 0.7030 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00047: val_loss improved from 1.60380 to 1.60082, saving model to weights\best_model_louvain.h5
# Epoch 48/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0497 - accuracy: 0.7677 - auc: 0.9473 - precision: 1.0000 - recall: 0.1010 - val_loss: 1.5975 - val_accuracy: 0.4000 - val_auc: 0.7140 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00048: val_loss improved from 1.60082 to 1.59751, saving model to weights\best_model_louvain.h5
# Epoch 49/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0072 - accuracy: 0.8081 - auc: 0.9706 - precision: 1.0000 - recall: 0.1111 - val_loss: 1.5938 - val_accuracy: 0.4000 - val_auc: 0.7194 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00049: val_loss improved from 1.59751 to 1.59384, saving model to weights\best_model_louvain.h5
# Epoch 50/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0033 - accuracy: 0.8586 - auc: 0.9677 - precision: 1.0000 - recall: 0.0808 - val_loss: 1.5904 - val_accuracy: 0.4400 - val_auc: 0.7212 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00050: val_loss improved from 1.59384 to 1.59045, saving model to weights\best_model_louvain.h5
# Epoch 51/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.9412 - accuracy: 0.8990 - auc: 0.9833 - precision: 1.0000 - recall: 0.1818 - val_loss: 1.5875 - val_accuracy: 0.4400 - val_auc: 0.7202 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00051: val_loss improved from 1.59045 to 1.58747, saving model to weights\best_model_louvain.h5
# Epoch 52/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9809 - accuracy: 0.8384 - auc: 0.9706 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.5846 - val_accuracy: 0.4400 - val_auc: 0.7182 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00052: val_loss improved from 1.58747 to 1.58456, saving model to weights\best_model_louvain.h5
# Epoch 53/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9754 - accuracy: 0.8586 - auc: 0.9757 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.5817 - val_accuracy: 0.4400 - val_auc: 0.7200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00053: val_loss improved from 1.58456 to 1.58170, saving model to weights\best_model_louvain.h5
# Epoch 54/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9628 - accuracy: 0.8485 - auc: 0.9774 - precision: 1.0000 - recall: 0.1313 - val_loss: 1.5780 - val_accuracy: 0.4800 - val_auc: 0.7178 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00054: val_loss improved from 1.58170 to 1.57803, saving model to weights\best_model_louvain.h5
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9708 - accuracy: 0.8788 - auc: 0.9723 - precision: 1.0000 - recall: 0.1414 - val_loss: 1.5741 - val_accuracy: 0.4800 - val_auc: 0.7184 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00055: val_loss improved from 1.57803 to 1.57415, saving model to weights\best_model_louvain.h5
# Epoch 56/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9638 - accuracy: 0.8586 - auc: 0.9840 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.5689 - val_accuracy: 0.5200 - val_auc: 0.7200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00056: val_loss improved from 1.57415 to 1.56890, saving model to weights\best_model_louvain.h5
# Epoch 57/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9615 - accuracy: 0.8788 - auc: 0.9825 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.5630 - val_accuracy: 0.5200 - val_auc: 0.7220 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00057: val_loss improved from 1.56890 to 1.56303, saving model to weights\best_model_louvain.h5
# Epoch 58/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0161 - accuracy: 0.8384 - auc: 0.9647 - precision: 1.0000 - recall: 0.0707 - val_loss: 1.5567 - val_accuracy: 0.4800 - val_auc: 0.7228 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00058: val_loss improved from 1.56303 to 1.55668, saving model to weights\best_model_louvain.h5
# Epoch 59/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9585 - accuracy: 0.8485 - auc: 0.9756 - precision: 1.0000 - recall: 0.1515 - val_loss: 1.5503 - val_accuracy: 0.4800 - val_auc: 0.7248 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00059: val_loss improved from 1.55668 to 1.55031, saving model to weights\best_model_louvain.h5
# Epoch 60/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9859 - accuracy: 0.8687 - auc: 0.9787 - precision: 1.0000 - recall: 0.1111 - val_loss: 1.5448 - val_accuracy: 0.4400 - val_auc: 0.7274 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00060: val_loss improved from 1.55031 to 1.54483, saving model to weights\best_model_louvain.h5
# Epoch 61/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9731 - accuracy: 0.9091 - auc: 0.9853 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.5408 - val_accuracy: 0.4400 - val_auc: 0.7260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00061: val_loss improved from 1.54483 to 1.54082, saving model to weights\best_model_louvain.h5
# Epoch 62/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9707 - accuracy: 0.8687 - auc: 0.9682 - precision: 1.0000 - recall: 0.1616 - val_loss: 1.5373 - val_accuracy: 0.4400 - val_auc: 0.7228 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00062: val_loss improved from 1.54082 to 1.53729, saving model to weights\best_model_louvain.h5
# Epoch 63/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9809 - accuracy: 0.8081 - auc: 0.9679 - precision: 1.0000 - recall: 0.1414 - val_loss: 1.5343 - val_accuracy: 0.4400 - val_auc: 0.7260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00063: val_loss improved from 1.53729 to 1.53430, saving model to weights\best_model_louvain.h5
# Epoch 64/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9429 - accuracy: 0.8586 - auc: 0.9734 - precision: 1.0000 - recall: 0.2323 - val_loss: 1.5320 - val_accuracy: 0.4000 - val_auc: 0.7248 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00064: val_loss improved from 1.53430 to 1.53197, saving model to weights\best_model_louvain.h5
# Epoch 65/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9774 - accuracy: 0.8788 - auc: 0.9776 - precision: 1.0000 - recall: 0.0909 - val_loss: 1.5300 - val_accuracy: 0.4000 - val_auc: 0.7216 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00065: val_loss improved from 1.53197 to 1.53002, saving model to weights\best_model_louvain.h5
# Epoch 66/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9190 - accuracy: 0.9091 - auc: 0.9889 - precision: 1.0000 - recall: 0.1212 - val_loss: 1.5293 - val_accuracy: 0.4000 - val_auc: 0.7156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00066: val_loss improved from 1.53002 to 1.52928, saving model to weights\best_model_louvain.h5
# Epoch 67/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9209 - accuracy: 0.8889 - auc: 0.9825 - precision: 1.0000 - recall: 0.1717 - val_loss: 1.5279 - val_accuracy: 0.4000 - val_auc: 0.7170 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00067: val_loss improved from 1.52928 to 1.52785, saving model to weights\best_model_louvain.h5
# Epoch 68/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9036 - accuracy: 0.9192 - auc: 0.9910 - precision: 1.0000 - recall: 0.1616 - val_loss: 1.5275 - val_accuracy: 0.3600 - val_auc: 0.7158 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00068: val_loss improved from 1.52785 to 1.52750, saving model to weights\best_model_louvain.h5
# Epoch 69/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9249 - accuracy: 0.8889 - auc: 0.9883 - precision: 1.0000 - recall: 0.1818 - val_loss: 1.5272 - val_accuracy: 0.3600 - val_auc: 0.7140 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00069: val_loss improved from 1.52750 to 1.52718, saving model to weights\best_model_louvain.h5
# Epoch 70/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9161 - accuracy: 0.8687 - auc: 0.9850 - precision: 1.0000 - recall: 0.1919 - val_loss: 1.5263 - val_accuracy: 0.3600 - val_auc: 0.7122 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00070: val_loss improved from 1.52718 to 1.52628, saving model to weights\best_model_louvain.h5
# Epoch 71/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9436 - accuracy: 0.8889 - auc: 0.9821 - precision: 1.0000 - recall: 0.1818 - val_loss: 1.5251 - val_accuracy: 0.3600 - val_auc: 0.7122 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00071: val_loss improved from 1.52628 to 1.52510, saving model to weights\best_model_louvain.h5
# Epoch 72/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9150 - accuracy: 0.9091 - auc: 0.9834 - precision: 1.0000 - recall: 0.1818 - val_loss: 1.5229 - val_accuracy: 0.3600 - val_auc: 0.7128 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00072: val_loss improved from 1.52510 to 1.52292, saving model to weights\best_model_louvain.h5
# Epoch 73/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9259 - accuracy: 0.8788 - auc: 0.9852 - precision: 1.0000 - recall: 0.1414 - val_loss: 1.5198 - val_accuracy: 0.3600 - val_auc: 0.7128 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00073: val_loss improved from 1.52292 to 1.51976, saving model to weights\best_model_louvain.h5
# Epoch 74/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9259 - accuracy: 0.9192 - auc: 0.9858 - precision: 1.0000 - recall: 0.1616 - val_loss: 1.5171 - val_accuracy: 0.3600 - val_auc: 0.7156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00074: val_loss improved from 1.51976 to 1.51707, saving model to weights\best_model_louvain.h5
# Epoch 75/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9136 - accuracy: 0.8586 - auc: 0.9747 - precision: 1.0000 - recall: 0.2323 - val_loss: 1.5133 - val_accuracy: 0.3600 - val_auc: 0.7212 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00075: val_loss improved from 1.51707 to 1.51327, saving model to weights\best_model_louvain.h5
# Epoch 76/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9404 - accuracy: 0.8990 - auc: 0.9836 - precision: 1.0000 - recall: 0.1717 - val_loss: 1.5087 - val_accuracy: 0.3600 - val_auc: 0.7254 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00076: val_loss improved from 1.51327 to 1.50871, saving model to weights\best_model_louvain.h5
# Epoch 77/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9411 - accuracy: 0.8788 - auc: 0.9809 - precision: 1.0000 - recall: 0.1515 - val_loss: 1.5054 - val_accuracy: 0.3600 - val_auc: 0.7274 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00077: val_loss improved from 1.50871 to 1.50536, saving model to weights\best_model_louvain.h5
# Epoch 78/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9376 - accuracy: 0.9091 - auc: 0.9864 - precision: 1.0000 - recall: 0.1515 - val_loss: 1.5029 - val_accuracy: 0.3600 - val_auc: 0.7322 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00078: val_loss improved from 1.50536 to 1.50289, saving model to weights\best_model_louvain.h5
# Epoch 79/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.9055 - accuracy: 0.8889 - auc: 0.9817 - precision: 1.0000 - recall: 0.2121 - val_loss: 1.5006 - val_accuracy: 0.3600 - val_auc: 0.7352 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00079: val_loss improved from 1.50289 to 1.50058, saving model to weights\best_model_louvain.h5
# Epoch 80/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9216 - accuracy: 0.8687 - auc: 0.9826 - precision: 1.0000 - recall: 0.2424 - val_loss: 1.4997 - val_accuracy: 0.3600 - val_auc: 0.7372 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00080: val_loss improved from 1.50058 to 1.49969, saving model to weights\best_model_louvain.h5
# Epoch 81/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9228 - accuracy: 0.8788 - auc: 0.9797 - precision: 1.0000 - recall: 0.2020 - val_loss: 1.5009 - val_accuracy: 0.3600 - val_auc: 0.7398 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00081: val_loss did not improve from 1.49969
# Epoch 82/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.9272 - accuracy: 0.9293 - auc: 0.9911 - precision: 1.0000 - recall: 0.1717 - val_loss: 1.5017 - val_accuracy: 0.3600 - val_auc: 0.7398 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00082: val_loss did not improve from 1.49969
# Epoch 83/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8746 - accuracy: 0.8990 - auc: 0.9887 - precision: 1.0000 - recall: 0.2020 - val_loss: 1.4999 - val_accuracy: 0.3600 - val_auc: 0.7386 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00083: val_loss did not improve from 1.49969
# Epoch 84/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8899 - accuracy: 0.8788 - auc: 0.9771 - precision: 1.0000 - recall: 0.2222 - val_loss: 1.4961 - val_accuracy: 0.3600 - val_auc: 0.7342 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00084: val_loss improved from 1.49969 to 1.49608, saving model to weights\best_model_louvain.h5
# Epoch 85/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8842 - accuracy: 0.8485 - auc: 0.9829 - precision: 1.0000 - recall: 0.2222 - val_loss: 1.4913 - val_accuracy: 0.3600 - val_auc: 0.7326 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00085: val_loss improved from 1.49608 to 1.49131, saving model to weights\best_model_louvain.h5
# Epoch 86/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.8866 - accuracy: 0.8788 - auc: 0.9864 - precision: 1.0000 - recall: 0.2020 - val_loss: 1.4871 - val_accuracy: 0.3600 - val_auc: 0.7324 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00086: val_loss improved from 1.49131 to 1.48714, saving model to weights\best_model_louvain.h5
# Epoch 87/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.8645 - accuracy: 0.8889 - auc: 0.9865 - precision: 1.0000 - recall: 0.2626 - val_loss: 1.4800 - val_accuracy: 0.3600 - val_auc: 0.7318 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00087: val_loss improved from 1.48714 to 1.48002, saving model to weights\best_model_louvain.h5
# Epoch 88/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.8550 - accuracy: 0.9293 - auc: 0.9898 - precision: 1.0000 - recall: 0.2222 - val_loss: 1.4721 - val_accuracy: 0.3600 - val_auc: 0.7302 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00088: val_loss improved from 1.48002 to 1.47206, saving model to weights\best_model_louvain.h5
# Epoch 89/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8432 - accuracy: 0.8990 - auc: 0.9898 - precision: 1.0000 - recall: 0.2828 - val_loss: 1.4634 - val_accuracy: 0.3600 - val_auc: 0.7306 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00089: val_loss improved from 1.47206 to 1.46341, saving model to weights\best_model_louvain.h5
# Epoch 90/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8954 - accuracy: 0.8990 - auc: 0.9878 - precision: 1.0000 - recall: 0.2020 - val_loss: 1.4529 - val_accuracy: 0.3600 - val_auc: 0.7336 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00090: val_loss improved from 1.46341 to 1.45295, saving model to weights\best_model_louvain.h5
# Epoch 91/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8581 - accuracy: 0.9293 - auc: 0.9885 - precision: 1.0000 - recall: 0.2626 - val_loss: 1.4405 - val_accuracy: 0.3600 - val_auc: 0.7366 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00091: val_loss improved from 1.45295 to 1.44047, saving model to weights\best_model_louvain.h5
# Epoch 92/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8381 - accuracy: 0.9293 - auc: 0.9935 - precision: 1.0000 - recall: 0.3232 - val_loss: 1.4314 - val_accuracy: 0.3600 - val_auc: 0.7404 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00092: val_loss improved from 1.44047 to 1.43140, saving model to weights\best_model_louvain.h5
# Epoch 93/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8407 - accuracy: 0.9394 - auc: 0.9884 - precision: 1.0000 - recall: 0.2626 - val_loss: 1.4234 - val_accuracy: 0.3600 - val_auc: 0.7454 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00093: val_loss improved from 1.43140 to 1.42338, saving model to weights\best_model_louvain.h5
# Epoch 94/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8436 - accuracy: 0.8990 - auc: 0.9887 - precision: 1.0000 - recall: 0.2323 - val_loss: 1.4159 - val_accuracy: 0.3600 - val_auc: 0.7510 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00094: val_loss improved from 1.42338 to 1.41588, saving model to weights\best_model_louvain.h5
# Epoch 95/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8173 - accuracy: 0.9293 - auc: 0.9956 - precision: 1.0000 - recall: 0.2222 - val_loss: 1.4093 - val_accuracy: 0.3600 - val_auc: 0.7594 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00095: val_loss improved from 1.41588 to 1.40928, saving model to weights\best_model_louvain.h5
# Epoch 96/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.8174 - accuracy: 0.9495 - auc: 0.9934 - precision: 1.0000 - recall: 0.3030 - val_loss: 1.4012 - val_accuracy: 0.3600 - val_auc: 0.7612 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00096: val_loss improved from 1.40928 to 1.40124, saving model to weights\best_model_louvain.h5
# Epoch 97/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8622 - accuracy: 0.8687 - auc: 0.9848 - precision: 1.0000 - recall: 0.2525 - val_loss: 1.3932 - val_accuracy: 0.3600 - val_auc: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00097: val_loss improved from 1.40124 to 1.39322, saving model to weights\best_model_louvain.h5
# Epoch 98/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.8401 - accuracy: 0.8889 - auc: 0.9856 - precision: 1.0000 - recall: 0.2828 - val_loss: 1.3836 - val_accuracy: 0.3600 - val_auc: 0.7778 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00098: val_loss improved from 1.39322 to 1.38359, saving model to weights\best_model_louvain.h5
# Epoch 99/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8500 - accuracy: 0.9192 - auc: 0.9876 - precision: 1.0000 - recall: 0.2929 - val_loss: 1.3750 - val_accuracy: 0.3600 - val_auc: 0.7834 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00099: val_loss improved from 1.38359 to 1.37498, saving model to weights\best_model_louvain.h5
# Epoch 100/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8640 - accuracy: 0.9091 - auc: 0.9875 - precision: 1.0000 - recall: 0.2727 - val_loss: 1.3661 - val_accuracy: 0.3200 - val_auc: 0.7854 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00100: val_loss improved from 1.37498 to 1.36610, saving model to weights\best_model_louvain.h5
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.26      1.00      0.41         6
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         3
#            4       1.00      0.67      0.80         3
#
#     accuracy                           0.32        25
#    macro avg       0.25      0.33      0.24        25
# weighted avg       0.18      0.32      0.20        25
#
# 1/1 [==============================] - 0s 30ms/step - loss: 1.3661 - accuracy: 0.3200 - auc: 0.7854 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
thr=0.95
n_genes = math.ceil((1 - thr) * adata.var.shape[0])


t=time.process_time()
tracemalloc.start()
# Run SHAP to identify marker genes
selected_genes, selected_genes_dict = smash.run_shap(adata, group_by='louvain', pct=0.5, restrict_top=("global", n_genes))

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# Memory Usage: 83.36 Mb
# Required Time: 9.625 sec

# %% [markdown]
# # Cluster Reconstructed Dataset (SMaSH)

# %%
print(f'\nTotal Marker genes ({len(selected_genes)}): ')
expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
# expr_data.to_csv('expr_processed.csv')
# expression data with only marker genes
expr_data = expr_data.loc[selected_genes]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

if "X_pca" not in rcdata.obsm and "neighbors" not in rcdata.uns:
  sc.pp.pca(rcdata, n_comps=50)
  sc.pp.neighbors(rcdata, n_pcs=50)
smash_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.5)
# Out:
# Total Marker genes (1205):
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 124 × 1205
#     obs: 'cluster'
#
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.5439
# Normalized Mutual Information (NMI): 0.7210
# Silhouette Score: 0.5173

# %% [markdown]
# # Cosg Marker Genes

# %%
import cosg as cosg
import importlib
importlib.reload(cosg)
# Out:
# <module 'cosg' from 'D:\\FYDP\\Implementation\\Notebooks\\python3.8\\lib\\site-packages\\cosg\\__init__.py'>

# %%
t=time.process_time()
tracemalloc.start()

cosg.cosg(adata,
    key_added='cosg',
        mu=1,
        n_genes_user=100,
               groupby='louvain')

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# **finished identifying marker genes by COSG**
# Memory Usage: 46.52 Mb
# Required Time: 0.09375 sec

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 124 × 24089
#     obs: 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'pca', 'neighbors', 'umap', 'louvain', 'louvain_colors', 'cosg'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
# cosg_marker_genes = np.unique(np.array(adata.uns['cosg']['names'])).tolist()
cosg_marker_genes = pd.unique(pd.DataFrame(adata.uns['cosg']['names']).values.ravel()).tolist()

# %%
len(cosg_marker_genes)
# Out:
# 500

# %% [markdown]
# # Cluster Reconstructed Dataset (Cosg)

# %%
cosg_expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
# expr_data.to_csv('expr_processed.csv')
# expression data with only high marker genes
cosg_expr_data = cosg_expr_data.loc[cosg_marker_genes]
# expr_data = expr_data.loc[marker_genes]
cosg_expr_data.shape

cgdata = sc.AnnData(X=cosg_expr_data.values.T)
cgdata.var_names = cosg_expr_data.index
cgdata.obs_names = cosg_expr_data.columns
cgdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(cgdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 124 × 500
#     obs: 'cluster'

# %%
if "X_pca" not in cgdata.obsm and "neighbors" not in cgdata.uns:
  sc.pp.pca(cgdata, n_comps=50)
  sc.pp.neighbors(cgdata, n_pcs=50)
cosg_sil_scores = cluster_with_louvain(cgdata, epochs=1, resolution=0.5)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.5439
# Normalized Mutual Information (NMI): 0.7210
# Silhouette Score: 0.6283

# %% [markdown]
# # Unified Marker Genes (CellTICS + COSG+ SMaSH)

# %%
silhouette_scores = {
    'celltics': cellTICS_sil_scores,
    'cosg': cosg_sil_scores,
    'smash': smash_sil_scores
}
print('silhouette scores: ', silhouette_scores)
methods_importance = calculate_importance(silhouette_scores)
print('methods_importance: ', methods_importance)
# Out:
# silhouette scores:  {'celltics': [0.5704483], 'cosg': [0.62825793], 'smash': [0.517258]}
# methods_importance:  {'celltics': 0.3324360030403171, 'cosg': 0.36612531366904044, 'smash': 0.3014386832906424}

# %%
# getting genes with highest weights
# methods_importance = {
#     'celltics': 0.349,
#     'cosg': 0.382,
#     'smash': 0.267
# }
UMG = pd.unique(score_marker_genes(high_markers,cosg_marker_genes,selected_genes, methods_importance, p=0.91))
# Out:
# total genes: 2399
# selected genes: 2183

# %%
len(UMG)
# Out:
# 2183

# %%
exp_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
exp_data = exp_data.loc[UMG]

ccdata = sc.AnnData(X=exp_data.values.T)
ccdata.var_names = exp_data.index
ccdata.obs_names = exp_data.columns
ccdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(ccdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 124 × 2183
#     obs: 'cluster'

# %%
if "X_pca" not in ccdata.obsm and "neighbors" not in ccdata.uns:
  sc.pp.pca(ccdata, n_comps=50)
  sc.pp.neighbors(ccdata, n_pcs=50)
cluster_with_louvain(ccdata, epochs=1, resolution=0.5)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.5439
# Normalized Mutual Information (NMI): 0.7210
# Silhouette Score: 0.5236
# [0.52355486]
