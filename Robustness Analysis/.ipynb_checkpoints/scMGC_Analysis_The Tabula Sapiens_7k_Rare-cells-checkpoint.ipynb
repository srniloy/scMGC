# %% [markdown]
# # Installation and Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import math
import pandas as pd
import scanpy as sc
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, silhouette_score
import time
import tracemalloc
from tensorflow.keras.regularizers import l2

# %%
import scvi

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# scanpy==1.9.6 anndata==0.9.2 umap==0.5.7 numpy==1.19.5 scipy==1.10.1 pandas==1.4.4 scikit-learn==1.3.2 statsmodels==0.14.1 igraph==0.11.8 louvain==0.8.2 pynndescent==0.5.13

# %% [markdown]
# # Defined Methods

# %% [markdown]
# ## Data Preprocessing

# %%
def data_init_x(path):
    print("\n==========================  Data Initialization  =================================\n")
    
    adata = sc.read_h5ad(path)

    adata.obs["cluster"] = adata.obs["cell_type"]

    print("Loaded Dataset Structure (preview 10×10):")

    # SAFE preview for sparse matrix
    X_preview = adata.X[:10, :10]
    if sp.issparse(X_preview):
        X_preview = X_preview.toarray()

    print(
        pd.DataFrame(
            X_preview,
            index=adata.obs.index[:10],
            columns=adata.var.index[:10]
        )
    )

    print("\nAnnData summary:")
    print(adata)

    print("\nTotal Clusters:")
    print(np.unique(adata.obs["cluster"]))

    print("\nCluster labels (first 20):")
    print(adata.obs["cluster"].head(20).values)

    # PCA + neighbors + UMAP
    sc.pp.pca(adata, n_comps=50)
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)

    print("\nExisting Cluster (UMAP)")
    sc.pl.umap(adata, color="cluster")

    return adata

# %%
def data_init(path):
    print("\n==========================  Data Initialization  =================================\n")
    data = pd.read_csv(path, index_col=0).astype('float64')
    clusters = data.columns
    clusters = [int(x) for x in [float(x) for x in clusters]]
    adata = sc.AnnData(X=(data.values.T))
    adata.var_names = data.index
    adata.obs_names = [f"cell-{i}" for i in range(1, len(clusters) + 1)]
    adata.obs["cluster"] = clusters
    print("Loaded Dataset Structure: ")
    print((pd.DataFrame(adata.X, index=adata.obs.index, columns=adata.var.index)).iloc[:10, :10])
    print(adata)
    print(f'Total Clusters: \n{np.unique(adata.obs["cluster"])}')
    print(f'Clusters: \n{adata.obs["cluster"]}')
    sc.pp.pca(adata, n_comps=50) 
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)
    print("Existing Cluster")
    sc.pl.umap(adata, color='cluster')
    return adata

# %%
def data_processing(adata):
  print("\n==========================  Data Processing  =================================\n")
  sc.pp.filter_cells(adata, min_genes=200)
  sc.pp.filter_genes(adata, min_cells=3)
  sc.pp.normalize_per_cell(adata)
  sc.pp.log1p(adata, copy=True)
  return adata

# %% [markdown]
# ## Remove Batch Effects

# %%
def remove_batch_effect(adata, batch_key='batch', n_pcs=20, method='harmony'):
    
    if batch_key not in adata.obs:
        raise KeyError(f"Batch key '{batch_key}' not found in adata.obs")
    
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    
    sc.pp.highly_variable_genes(adata, flavor='cell_ranger', n_top_genes=2000)
    adata = adata[:, adata.var['highly_variable']].copy()
    sc.pp.scale(adata, max_value=10)
    
    sc.tl.pca(adata, n_comps=n_pcs, svd_solver='arpack')
    
    if method.lower() == 'harmony':
        ho = hm.run_harmony(adata.obsm['X_pca'], adata.obs, batch_key)
        adata.obsm['X_pca_harmony'] = ho.Z_corr
        sc.pp.neighbors(adata, use_rep='X_pca_harmony')
    elif method.lower() == 'bbknn':
        sce.pp.bbknn(adata, batch_key=batch_key, n_pcs=n_pcs)
    else:
        raise ValueError("Method must be 'harmony' or 'bbknn'.")
    
    sc.tl.umap(adata)

# %% [markdown]
# ## Denoising

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import scanpy as sc
import numpy as np

def Denoise(adata):
    
    # Step 1: Load and preprocess data
    X = adata.X  # Assuming adata.X is in sparse format
    X = X.toarray() if hasattr(X, "toarray") else X  # Convert to dense if sparse
    
    # Normalize and scale data
    X = sc.pp.log1p(X, copy=True)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    # Step 2: Add sparse noise to mimic biological dropout
    def add_sparse_noise(data, dropout_rate=0.1):
        """
        Adds sparse dropout noise to mimic missing data in scRNA-seq.
        """
        noisy_data = data.copy()
        mask = np.random.binomial(1, dropout_rate, size=data.shape)  # Create dropout mask
        noisy_data[mask == 1] = 0  # Set selected values to zero
        return noisy_data
    
    X_noisy = add_sparse_noise(X)
    
    # Step 3: Define sparse-aware denoising autoencoder
    input_dim = X.shape[1]
    
    # Encoder
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(512, activation='relu')(input_layer)
    encoded = BatchNormalization()(encoded)
    encoded = Dropout(0.2)(encoded)
    latent_space = Dense(128, activation='relu')(encoded)
    
    # Decoder
    decoded = Dense(512, activation='relu')(latent_space)
    decoded = BatchNormalization()(decoded)
    decoded = Dropout(0.2)(decoded)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    # Autoencoder model
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    
    # Custom sparse-aware loss
    def sparse_mse(y_true, y_pred):
        """
        Custom loss to preserve zeros and penalize large changes to nonzero values.
        """
        mask = tf.cast(tf.equal(y_true, 0.0), tf.float32)  # Mask for zeros in original data
        nonzero_loss = tf.reduce_mean(tf.square((1 - mask) * (y_true - y_pred)))  # Penalize changes to nonzeros
        zero_loss = tf.reduce_mean(tf.square(mask * y_pred))  # Penalize predicted values where true value is zero
        return nonzero_loss + 0.1 * zero_loss  # Combine losses with weight for zero preservation
    
    # Compile the model
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                        loss=sparse_mse,
                        metrics=['mae'])
    
    # Step 4: Train the model
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
    X_noisy_train, X_noisy_val = train_test_split(X_noisy, test_size=0.2, random_state=42)
    
    history = autoencoder.fit(
        X_noisy_train, X_train,
        validation_data=(X_noisy_val, X_val),
        epochs=200,
        batch_size=256,
        shuffle=True,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
        ]
    )
    
    # Step 5: Denoise the data
    X_denoised = autoencoder.predict(X_noisy)
    
    # Save the denoised output
    adata.X = scaler.inverse_transform(X_denoised)  # Inverse scaling
    return adata

# %% [markdown]
# ## Clustering

# %%
def cluster_with_louvain(adata, epochs, resolution=2.5):
  print("\n========================== Clustering With Louvain =================================\n")
  # if "X_pca" not in adata.obsm and "neighbors" not in adata.uns:
  sc.pp.pca(adata)
  sc.pp.neighbors(adata)
  sil_scores = []

  for i in range(0, epochs):
    sc.tl.louvain(adata, resolution)

    print(f"\nClustering epoch {i+1} ------------------")
    ari = adjusted_rand_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Adjusted Rand Index (ARI): {ari:.4f}")

    nmi = normalized_mutual_info_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Normalized Mutual Information (NMI): {nmi:.4f}")

    X = adata.obsm["X_pca"]
    sil_score = silhouette_score(X, adata.obs['louvain'])
    sil_scores.append(sil_score)
    print(f"Silhouette Score: {sil_score:.4f}\n")

      
  sc.tl.umap(adata)
  sc.pl.umap(adata, color='louvain')
  return sil_scores

# %% [markdown]
# ## Identify Marker Gene

# %% [markdown]
# ### CellTICS

# %%
# Define fphi - High markers
def fphi(x):
    normalized = (x + 1).div(x.max(axis=1) + 1, axis=0)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)
    zp = normalized.mul(zt, axis=0)
    return zp

# Define frho - Low markers
def frho(x):
    normalized = (1 / (x + 1)).mul(x.min(axis=1) + 1, axis=0)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)
    zp = normalized.mul(zt, axis=0)
    return zp

def CellTICS_marker_genes(adata, thr1=0.95, thr2=0.9):
    print("\n====================== Identify Marker Gene With CellTICS ============================\n")
    print("Expression Values of Genes: \n")
    
    X_dense = adata.X
    if hasattr(X_dense, 'toarray'):
        X_dense = X_dense.toarray()
    
    expr_data = pd.DataFrame(
        X_dense.T,
        index=adata.var_names,
        columns=adata.obs_names
    )
    
    louvain_labels = pd.Series(adata.obs['louvain'].values, index=adata.obs_names)
    print(expr_data.iloc[:10, :10])
    print(adata)

    print("\nAverage the cell expr data according to the clusters:\n")
    avg_expr_data = expr_data.T.groupby(louvain_labels).mean().T
    print(avg_expr_data.iloc[:10, :])

    phi = fphi(avg_expr_data)
    rho = frho(avg_expr_data)

    gnm = phi.index.values 
    ctpnm = phi.columns.values

    phi = np.array(phi)
    rho = np.array(rho)

    nummkg1 = math.ceil((1 - thr1) * phi.shape[0]) 
    nummkg2 = math.ceil((1 - thr2) * phi.shape[0]) 

    alpha = [] 
    beta = []
    for i in range(0, phi.shape[1]):
        alpha.append(np.quantile(phi[:, i], thr1))
        beta.append(np.quantile(rho[:, i], thr2))

    mkh = [] 
    mkl = [] 
    for i in range(0, phi.shape[1]):
        high_markers = gnm[phi[:, i] >= alpha[i]][0:nummkg1]
        low_markers = gnm[rho[:, i] >= beta[i]][0:nummkg2]
        mkh = np.concatenate([mkh, high_markers], axis=0) if len(mkh) > 0 else high_markers
        mkl = np.concatenate([mkl, low_markers], axis=0) if len(mkl) > 0 else low_markers

    mkh = mkh.reshape(nummkg1, phi.shape[1])
    mkl = mkl.reshape(nummkg2, rho.shape[1])
    mkh = pd.DataFrame(mkh, columns=ctpnm)
    mkl = pd.DataFrame(mkl, columns=ctpnm)

    print("\nHigh Marker Genes for each cluster/type: \n")
    print(mkh.iloc[:10, :])

    print("\nLow Marker Genes for each cluster/type: \n")
    print(mkl.iloc[:10, :])

    return mkh, mkl

# %%
# getting list of all high and low marker genes
def get_unique_marker_genes(high_markers):
  unique_high_markers = high_markers
  unique_high_markers = pd.unique(unique_high_markers.values.ravel()).tolist()
  print(f"\nTotal Unique High Marker Gene for all together {len(unique_high_markers)}: ")
  return unique_high_markers

# %% [markdown]
# ## Calculate Importance

# %%
def calculate_importance(silhouette_scores):
    avg_scores = {k: sum(v) / len(v) for k, v in silhouette_scores.items()}
    
    total = sum(avg_scores.values())
    return {k: v / total for k, v in avg_scores.items()}

# %% [markdown]
# ## Unified Marker Genes (Weight Based)

# %%
from collections import defaultdict

def score_marker_genes(celltics_genes, smash_genes, cosg_genes, importance, p=1.0):
    
    gene_weights = defaultdict(float)
    
    for gene in celltics_genes:
        gene_weights[gene] += importance['celltics']
        
    for gene in smash_genes:
        gene_weights[gene] += importance['smash']
        
    for gene in cosg_genes:
        gene_weights[gene] += importance['cosg']
    
    selected_genes = sorted(gene_weights.items(), key=lambda x: x[1], reverse=True) # selecting genes with highest weight

    print(f'total genes: {len(selected_genes)}')
    
    top_n = int(len(selected_genes) * p)

    print(f'selected genes: {top_n}')
    
    return [gene for gene, weight in selected_genes[:top_n]]

# %% [markdown]
# # Implementations____________

# %%
import scipy.sparse as sp

# %%
# dataset_path = "88930108-9c98-43a7-826d-ce454dd0c930.h5ad"


# adata = data_processing(adata)

# adata = Denoise(adata)

adata = sc.read_h5ad("new-7k-processed.h5ad")
adata = data_init_x(dataset_path)
adata = data_processing(adata)
# Out:
# ==========================  Data Initialization  =================================
#
# Loaded Dataset Structure (preview 10×10):
#                                                    ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  ENSG00000001084  ENSG00000001167
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96D3         1.264499         0.000000         0.009827         0.122905         0.000000              0.0         0.000000         0.317563         0.225919         0.913371
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A3         0.114413         0.000000         0.157242         0.015546         0.017979              0.0         0.004115         0.013514         0.128653         0.001648
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A2         0.002765         0.000000         0.084898         0.105043         0.074672              0.0         0.000000         0.038033         0.102547         0.072099
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96H2         0.856974         0.000000         0.149996         0.000000         0.000000              0.0         0.075223         0.005565         0.000000         0.000000
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96E3         0.654579         0.161909         0.107880         0.000000         0.000000              0.0         0.000000         0.186517         0.012935         0.000000
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B3         0.083752         0.000000         0.150348         0.048713         0.212784              0.0         0.000000         0.083752         0.012403         0.012403
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C2         1.582033         0.093089         0.407333         0.036836         0.093089              0.0         0.072363         0.585273         0.227259         0.093089
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96F3         0.625072         0.000000         0.150058         0.159065         0.189967              0.0         0.022865         0.644574         0.021837         0.152769
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C3         0.054918         0.000000         0.116792         0.076939         0.101324              0.0         0.000000         0.000000         0.145672         0.006253
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B2         0.033083         0.000000         0.078523         0.074071         0.163642              0.0         0.000000         0.046933         0.046933         0.087369
#
# AnnData summary:
# AnnData object with n_obs × n_vars = 7276 × 60606
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'compartment_colors', 'donor_id_colors', 'leiden', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'
#
# Total Clusters:
# ['male germ cell' 'oocyte' 'spermatid' 'spermatocyte' 'spermatogonium']
#
# Cluster labels (first 20):
# ['oocyte', 'oocyte', 'oocyte', 'oocyte', 'oocyte', ..., 'spermatid', 'male germ cell', 'spermatocyte', 'spermatid', 'spermatocyte']
# Length: 20
# Categories (5, object): ['male germ cell', 'spermatocyte', 'spermatid', 'spermatogonium', 'oocyte']
# computing PCA
#     with n_comps=50
#     finished (0:00:25)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:07)
#
# Existing Cluster (UMAP)
# ==========================  Data Processing  =================================
#
# filtered out 18437 genes that are detected in less than 3 cells
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
# Count cells per type
cell_counts = adata.obs['cell_type'].value_counts()

# Total cells
total_cells = adata.n_obs

# Create summary table
cell_summary = pd.DataFrame({
    'cell_count': cell_counts,
})

cell_summary['percentage'] = (cell_summary['cell_count'] / total_cells) * 100

# Define rare threshold (5%)
rare_threshold = 5

rare_cells = cell_summary[cell_summary['percentage'] < rare_threshold]

print("=== Cell Type Distribution ===")
print(cell_summary)

print("\n=== Rare Cell Types (<5%) ===")
print(rare_cells)
# Out:
# === Cell Type Distribution ===
#                 cell_count  percentage
# spermatid             4009   55.098955
# spermatocyte          3070   42.193513
# male germ cell         116    1.594283
# spermatogonium          64    0.879604
# oocyte                  17    0.233645
#
# === Rare Cell Types (<5%) ===
#                 cell_count  percentage
# male germ cell         116    1.594283
# spermatogonium          64    0.879604
# oocyte                  17    0.233645

# %%
rare_cell_types = rare_cells.index.tolist()

adata = adata[
    adata.obs['cell_type'].isin(rare_cell_types)
].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 197 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'compartment_colors', 'donor_id_colors', 'leiden', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap', 'cluster_colors'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # CellTICS Marker Genes

# %%
# adata.write_h5ad("new-7k-processed.h5ad")

# %%
adata.obs["cluster"]
# Out:
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96D3            oocyte
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A3            oocyte
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A2            oocyte
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96H2            oocyte
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96E3            oocyte
#                                                           ...
# TSP25_Testis_NA_10X_1_1_TTCATGTCATGAAGCG             spermatogonium
# TSP25_Testis_NA_10X_1_1_TTCCTAAAGCCTCAGC             male germ cell
# TSP25_Testis_NA_10X_1_1_TTCTCTCTCTAGGCAT             male germ cell
# TSP25_Testis_NA_10X_1_1_TTTCATGAGGCTATCT             male germ cell
# TSP25_Testis_NA_10X_1_1_TTTCATGAGTCTCTGA             male germ cell
# Name: cluster, Length: 197, dtype: category
# Categories (3, object): ['male germ cell', 'spermatogonium', 'oocyte']

# %%
cluster_with_louvain(adata, epochs=1, resolution=0.1)
t=time.process_time()
tracemalloc.start()

high_markers, low_markers = CellTICS_marker_genes(adata, thr1=0.80, thr2= 0.80)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()


high_markers = get_unique_marker_genes(high_markers)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.9447
# Normalized Mutual Information (NMI): 0.9250
# Silhouette Score: 0.1900
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:00)
# ====================== Identify Marker Gene With CellTICS ============================
#
# Expression Values of Genes:
#
#                  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96D3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A2  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96H2  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96E3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C2  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96F3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C3  TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B2
# ENSG00000000003                                           1.010445                                           0.102498                                           0.002113                                           0.753235                                           0.536780                                           0.067352                                           1.344120                                           0.444233                                           0.044570                                           0.031380
# ENSG00000000005                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.132772                                           0.000000                                           0.079090                                           0.000000                                           0.000000                                           0.000000
# ENSG00000000419                                           0.007853                                           0.140867                                           0.064861                                           0.131839                                           0.088466                                           0.120908                                           0.346076                                           0.106645                                           0.094784                                           0.074481
# ENSG00000000457                                           0.098212                                           0.013927                                           0.080251                                           0.000000                                           0.000000                                           0.039175                                           0.031296                                           0.113046                                           0.062441                                           0.070258
# ENSG00000000460                                           0.000000                                           0.016106                                           0.057048                                           0.000000                                           0.000000                                           0.171118                                           0.079090                                           0.135008                                           0.082231                                           0.155218
# ENSG00000000938                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000                                           0.000000
# ENSG00000000971                                           0.000000                                           0.003686                                           0.000000                                           0.066117                                           0.000000                                           0.000000                                           0.061481                                           0.016250                                           0.000000                                           0.000000
# ENSG00000001036                                           0.253761                                           0.012107                                           0.029056                                           0.004891                                           0.152951                                           0.067352                                           0.497257                                           0.458093                                           0.000000                                           0.044517
# ENSG00000001084                                           0.180529                                           0.115255                                           0.078344                                           0.000000                                           0.010607                                           0.009974                                           0.193082                                           0.015520                                           0.118222                                           0.044517
# ENSG00000001167                                           0.729863                                           0.001476                                           0.055082                                           0.000000                                           0.000000                                           0.009974                                           0.079090                                           0.108571                                           0.005075                                           0.082871
# AnnData object with n_obs × n_vars = 197 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'compartment_colors', 'donor_id_colors', 'leiden', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap', 'cluster_colors', 'louvain', 'louvain_colors'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'
#
# Average the cell expr data according to the clusters:
#
#                         0         1         2
# ENSG00000000003  0.159098  0.134463  0.305957
# ENSG00000000005  0.000000  0.000000  0.012462
# ENSG00000000419  0.244747  0.294388  0.130239
# ENSG00000000457  0.136681  0.149220  0.037730
# ENSG00000000460  0.214444  0.295726  0.094121
# ENSG00000000938  0.000000  0.000000  0.000000
# ENSG00000000971  0.002075  0.000000  0.040546
# ENSG00000001036  0.036316  0.000000  0.161207
# ENSG00000001084  0.191483  0.285070  0.087862
# ENSG00000001167  0.115966  0.087101  0.063576
#
# High Marker Genes for each cluster/type:
#
#                  0                1                2
# 0  ENSG00000000003  ENSG00000000460  ENSG00000001036
# 1  ENSG00000001084  ENSG00000001460  ENSG00000001461
# 2  ENSG00000001497  ENSG00000001629  ENSG00000002330
# 3  ENSG00000002549  ENSG00000002746  ENSG00000002919
# 4  ENSG00000003096  ENSG00000003147  ENSG00000003393
# 5  ENSG00000004059  ENSG00000004142  ENSG00000004455
# 6  ENSG00000004468  ENSG00000004478  ENSG00000004487
# 7  ENSG00000004534  ENSG00000004776  ENSG00000004779
# 8  ENSG00000004864  ENSG00000004961  ENSG00000004975
# 9  ENSG00000005020  ENSG00000005022  ENSG00000005059
#
# Low Marker Genes for each cluster/type:
#
#                  0                1                2
# 0  ENSG00000000419  ENSG00000000457  ENSG00000000460
# 1  ENSG00000001036  ENSG00000001084  ENSG00000001460
# 2  ENSG00000001461  ENSG00000001497  ENSG00000001629
# 3  ENSG00000002016  ENSG00000002330  ENSG00000002549
# 4  ENSG00000002746  ENSG00000002919  ENSG00000003096
# 5  ENSG00000003147  ENSG00000003393  ENSG00000003509
# 6  ENSG00000003756  ENSG00000004059  ENSG00000004142
# 7  ENSG00000004455  ENSG00000004468  ENSG00000004487
# 8  ENSG00000004534  ENSG00000004779  ENSG00000004838
# 9  ENSG00000004864  ENSG00000004897  ENSG00000004961
# Memory Usage: 98.96 Mb
# Required Time: 0.109375 sec
#
# Total Unique High Marker Gene for all together 8925:

# %% [markdown]
# # Cluster Reconstructed Dataset (CellTICS)

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)
expr_data = expr_data.loc[high_markers]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 197 × 8925
#     obs: 'cluster'

# %%
# rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

# %%
cellTICS_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.07)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.9447
# Normalized Mutual Information (NMI): 0.9250
# Silhouette Score: 0.2084
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:00)

# %% [markdown]
# # Smash Marker Genes

# %%
# adata.write_h5ad("new_processed.h5ad")

# %%
# adata = sc.read_h5ad("new_processed.h5ad")

# %%
import os
import smashpy

smash = smashpy.smashpy()

X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

if np.any(np.isnan(X_dense)):
    if hasattr(adata.X, 'toarray'):
        adata.X = np.nan_to_num(X_dense)
    else:
        adata.X = np.nan_to_num(adata.X)

if not os.path.exists('Figures'):
    os.makedirs('Figures')

# smash.DNN(adata, group_by='louvain')
# Out:
#  * Initialising ...

# %%
# import numpy as np
# import scipy.sparse as sp

# clusters = adata.obs["louvain"].unique()

# X_bulk = []
# for c in clusters:
#     idx = adata.obs["louvain"] == c
#     Xc = adata.X[idx]
#     X_bulk.append(Xc.mean(axis=0))

# X_bulk = np.vstack([x.A if sp.issparse(x) else x for x in X_bulk])

# adata_bulk = sc.AnnData(
#     X=X_bulk,
#     var=adata.var.copy(),
#     obs=pd.DataFrame({"cluster": clusters})
# )

# print(adata_bulk)

# %%
# 1. Select HVGs FIRST
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    flavor="seurat"
)

adata_hvg = adata[:, adata.var.highly_variable].copy()

# 2. Convert to dense and replace X
if hasattr(adata_hvg.X, 'toarray'):
    adata_hvg.X = adata_hvg.X.toarray()

# 3. Train Smash DNN on HVGs
smash.DNN(adata_hvg, group_by='louvain')

t = time.process_time()
tracemalloc.start()

# 4. Run SHAP on the SAME adata_hvg
selected_genes, selected_genes_dict = smash.run_shap(
    adata_hvg,
    group_by='louvain',
    pct=0.2,
    restrict_top=("global", 1000)
)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb')
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 32)                64032
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32)                128
# _________________________________________________________________
# activation_8 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 16)                528
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16)                64
# _________________________________________________________________
# activation_9 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 64,803
# Trainable params: 64,707
# Non-trainable params: 96
# _________________________________________________________________
# None
# Epoch 1/100
# 2/2 [==============================] - 1s 353ms/step - loss: 1.1648 - accuracy: 0.5987 - auc: 0.7860 - precision: 0.6915 - recall: 0.4140 - val_loss: 0.8519 - val_accuracy: 0.6000 - val_auc: 0.8719 - val_precision: 0.7500 - val_recall: 0.6000
#
# Epoch 00001: val_loss improved from inf to 0.85193, saving model to weights\best_model_louvain.h5
# Epoch 2/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9478 - accuracy: 0.6815 - auc: 0.8908 - precision: 0.8182 - recall: 0.5159 - val_loss: 0.8073 - val_accuracy: 0.6000 - val_auc: 0.8822 - val_precision: 0.9600 - val_recall: 0.6000
#
# Epoch 00002: val_loss improved from 0.85193 to 0.80725, saving model to weights\best_model_louvain.h5
# Epoch 3/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.8738 - accuracy: 0.6815 - auc: 0.9133 - precision: 0.8800 - recall: 0.5605 - val_loss: 0.7729 - val_accuracy: 0.6000 - val_auc: 0.8867 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00003: val_loss improved from 0.80725 to 0.77295, saving model to weights\best_model_louvain.h5
# Epoch 4/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.8156 - accuracy: 0.8153 - auc: 0.9392 - precision: 0.8958 - recall: 0.5478 - val_loss: 0.7456 - val_accuracy: 0.6250 - val_auc: 0.8952 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00004: val_loss improved from 0.77295 to 0.74563, saving model to weights\best_model_louvain.h5
# Epoch 5/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.7778 - accuracy: 0.8471 - auc: 0.9631 - precision: 0.9583 - recall: 0.5860 - val_loss: 0.7230 - val_accuracy: 0.6500 - val_auc: 0.9144 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00005: val_loss improved from 0.74563 to 0.72297, saving model to weights\best_model_louvain.h5
# Epoch 6/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7702 - accuracy: 0.8471 - auc: 0.9668 - precision: 0.9592 - recall: 0.5987 - val_loss: 0.7037 - val_accuracy: 0.7250 - val_auc: 0.9411 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00006: val_loss improved from 0.72297 to 0.70367, saving model to weights\best_model_louvain.h5
# Epoch 7/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.7588 - accuracy: 0.8726 - auc: 0.9762 - precision: 0.9904 - recall: 0.6561 - val_loss: 0.6870 - val_accuracy: 0.7750 - val_auc: 0.9572 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00007: val_loss improved from 0.70367 to 0.68695, saving model to weights\best_model_louvain.h5
# Epoch 8/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7272 - accuracy: 0.8854 - auc: 0.9823 - precision: 0.9820 - recall: 0.6943 - val_loss: 0.6719 - val_accuracy: 0.8500 - val_auc: 0.9672 - val_precision: 1.0000 - val_recall: 0.5750
#
# Epoch 00008: val_loss improved from 0.68695 to 0.67191, saving model to weights\best_model_louvain.h5
# Epoch 9/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7083 - accuracy: 0.9108 - auc: 0.9875 - precision: 1.0000 - recall: 0.7452 - val_loss: 0.6582 - val_accuracy: 0.8500 - val_auc: 0.9716 - val_precision: 1.0000 - val_recall: 0.5750
#
# Epoch 00009: val_loss improved from 0.67191 to 0.65823, saving model to weights\best_model_louvain.h5
# Epoch 10/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6801 - accuracy: 0.9427 - auc: 0.9873 - precision: 0.9667 - recall: 0.7389 - val_loss: 0.6458 - val_accuracy: 0.8500 - val_auc: 0.9731 - val_precision: 1.0000 - val_recall: 0.5750
#
# Epoch 00010: val_loss improved from 0.65823 to 0.64582, saving model to weights\best_model_louvain.h5
# Epoch 11/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7247 - accuracy: 0.9045 - auc: 0.9861 - precision: 1.0000 - recall: 0.6943 - val_loss: 0.6346 - val_accuracy: 0.9000 - val_auc: 0.9752 - val_precision: 1.0000 - val_recall: 0.5750
#
# Epoch 00011: val_loss improved from 0.64582 to 0.63461, saving model to weights\best_model_louvain.h5
# Epoch 12/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6698 - accuracy: 0.9490 - auc: 0.9887 - precision: 0.9829 - recall: 0.7325 - val_loss: 0.6242 - val_accuracy: 0.9000 - val_auc: 0.9775 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00012: val_loss improved from 0.63461 to 0.62418, saving model to weights\best_model_louvain.h5
# Epoch 13/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6867 - accuracy: 0.9108 - auc: 0.9891 - precision: 1.0000 - recall: 0.7516 - val_loss: 0.6142 - val_accuracy: 0.9250 - val_auc: 0.9808 - val_precision: 1.0000 - val_recall: 0.6000
#
# Epoch 00013: val_loss improved from 0.62418 to 0.61424, saving model to weights\best_model_louvain.h5
# Epoch 14/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6808 - accuracy: 0.9299 - auc: 0.9870 - precision: 0.9831 - recall: 0.7389 - val_loss: 0.6048 - val_accuracy: 0.9250 - val_auc: 0.9852 - val_precision: 1.0000 - val_recall: 0.6500
#
# Epoch 00014: val_loss improved from 0.61424 to 0.60478, saving model to weights\best_model_louvain.h5
# Epoch 15/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6609 - accuracy: 0.9427 - auc: 0.9938 - precision: 1.0000 - recall: 0.7771 - val_loss: 0.5958 - val_accuracy: 0.9750 - val_auc: 0.9878 - val_precision: 1.0000 - val_recall: 0.6750
#
# Epoch 00015: val_loss improved from 0.60478 to 0.59578, saving model to weights\best_model_louvain.h5
# Epoch 16/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6599 - accuracy: 0.9299 - auc: 0.9909 - precision: 0.9832 - recall: 0.7452 - val_loss: 0.5872 - val_accuracy: 0.9750 - val_auc: 0.9917 - val_precision: 1.0000 - val_recall: 0.6750
#
# Epoch 00016: val_loss improved from 0.59578 to 0.58720, saving model to weights\best_model_louvain.h5
# Epoch 17/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6427 - accuracy: 0.9045 - auc: 0.9906 - precision: 0.9760 - recall: 0.7771 - val_loss: 0.5791 - val_accuracy: 0.9750 - val_auc: 0.9941 - val_precision: 1.0000 - val_recall: 0.7000
#
# Epoch 00017: val_loss improved from 0.58720 to 0.57914, saving model to weights\best_model_louvain.h5
# Epoch 18/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6304 - accuracy: 0.9682 - auc: 0.9963 - precision: 1.0000 - recall: 0.8025 - val_loss: 0.5715 - val_accuracy: 1.0000 - val_auc: 0.9964 - val_precision: 1.0000 - val_recall: 0.7250
#
# Epoch 00018: val_loss improved from 0.57914 to 0.57153, saving model to weights\best_model_louvain.h5
# Epoch 19/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6122 - accuracy: 0.9618 - auc: 0.9966 - precision: 0.9922 - recall: 0.8089 - val_loss: 0.5642 - val_accuracy: 1.0000 - val_auc: 0.9978 - val_precision: 1.0000 - val_recall: 0.7500
#
# Epoch 00019: val_loss improved from 0.57153 to 0.56421, saving model to weights\best_model_louvain.h5
# Epoch 20/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6054 - accuracy: 0.9809 - auc: 0.9987 - precision: 1.0000 - recall: 0.7898 - val_loss: 0.5573 - val_accuracy: 1.0000 - val_auc: 0.9983 - val_precision: 1.0000 - val_recall: 0.8250
#
# Epoch 00020: val_loss improved from 0.56421 to 0.55729, saving model to weights\best_model_louvain.h5
# Epoch 21/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6194 - accuracy: 0.9427 - auc: 0.9955 - precision: 1.0000 - recall: 0.7707 - val_loss: 0.5506 - val_accuracy: 1.0000 - val_auc: 0.9988 - val_precision: 1.0000 - val_recall: 0.8250
#
# Epoch 00021: val_loss improved from 0.55729 to 0.55057, saving model to weights\best_model_louvain.h5
# Epoch 22/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5866 - accuracy: 0.9745 - auc: 0.9991 - precision: 1.0000 - recall: 0.8471 - val_loss: 0.5440 - val_accuracy: 1.0000 - val_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.8500
#
# Epoch 00022: val_loss improved from 0.55057 to 0.54397, saving model to weights\best_model_louvain.h5
# Epoch 23/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5853 - accuracy: 0.9873 - auc: 0.9981 - precision: 1.0000 - recall: 0.8280 - val_loss: 0.5371 - val_accuracy: 1.0000 - val_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.8500
#
# Epoch 00023: val_loss improved from 0.54397 to 0.53714, saving model to weights\best_model_louvain.h5
# Epoch 24/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6140 - accuracy: 0.9490 - auc: 0.9969 - precision: 1.0000 - recall: 0.7643 - val_loss: 0.5302 - val_accuracy: 1.0000 - val_auc: 0.9988 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00024: val_loss improved from 0.53714 to 0.53019, saving model to weights\best_model_louvain.h5
# Epoch 25/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5961 - accuracy: 0.9427 - auc: 0.9923 - precision: 0.9922 - recall: 0.8153 - val_loss: 0.5234 - val_accuracy: 1.0000 - val_auc: 0.9988 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00025: val_loss improved from 0.53019 to 0.52337, saving model to weights\best_model_louvain.h5
# Epoch 26/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5725 - accuracy: 0.9873 - auc: 0.9987 - precision: 1.0000 - recall: 0.8917 - val_loss: 0.5167 - val_accuracy: 1.0000 - val_auc: 0.9987 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00026: val_loss improved from 0.52337 to 0.51672, saving model to weights\best_model_louvain.h5
# Epoch 27/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5667 - accuracy: 0.9682 - auc: 0.9983 - precision: 1.0000 - recall: 0.8344 - val_loss: 0.5102 - val_accuracy: 1.0000 - val_auc: 0.9989 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00027: val_loss improved from 0.51672 to 0.51021, saving model to weights\best_model_louvain.h5
# Epoch 28/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6018 - accuracy: 0.9618 - auc: 0.9981 - precision: 1.0000 - recall: 0.8025 - val_loss: 0.5039 - val_accuracy: 1.0000 - val_auc: 0.9991 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00028: val_loss improved from 0.51021 to 0.50386, saving model to weights\best_model_louvain.h5
# Epoch 29/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5626 - accuracy: 0.9745 - auc: 0.9991 - precision: 1.0000 - recall: 0.8790 - val_loss: 0.4979 - val_accuracy: 1.0000 - val_auc: 0.9991 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00029: val_loss improved from 0.50386 to 0.49790, saving model to weights\best_model_louvain.h5
# Epoch 30/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5476 - accuracy: 0.9873 - auc: 0.9995 - precision: 1.0000 - recall: 0.8662 - val_loss: 0.4922 - val_accuracy: 1.0000 - val_auc: 0.9991 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00030: val_loss improved from 0.49790 to 0.49215, saving model to weights\best_model_louvain.h5
# Epoch 31/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5403 - accuracy: 1.0000 - auc: 0.9998 - precision: 1.0000 - recall: 0.8981 - val_loss: 0.4861 - val_accuracy: 1.0000 - val_auc: 0.9995 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00031: val_loss improved from 0.49215 to 0.48609, saving model to weights\best_model_louvain.h5
# Epoch 32/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5418 - accuracy: 0.9936 - auc: 0.9998 - precision: 1.0000 - recall: 0.8662 - val_loss: 0.4802 - val_accuracy: 1.0000 - val_auc: 0.9995 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00032: val_loss improved from 0.48609 to 0.48017, saving model to weights\best_model_louvain.h5
# Epoch 33/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5395 - accuracy: 0.9936 - auc: 0.9996 - precision: 0.9928 - recall: 0.8726 - val_loss: 0.4739 - val_accuracy: 1.0000 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00033: val_loss improved from 0.48017 to 0.47390, saving model to weights\best_model_louvain.h5
# Epoch 34/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5530 - accuracy: 0.9618 - auc: 0.9975 - precision: 0.9924 - recall: 0.8280 - val_loss: 0.4679 - val_accuracy: 1.0000 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00034: val_loss improved from 0.47390 to 0.46788, saving model to weights\best_model_louvain.h5
# Epoch 35/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5249 - accuracy: 0.9682 - auc: 0.9985 - precision: 0.9929 - recall: 0.8854 - val_loss: 0.4625 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00035: val_loss improved from 0.46788 to 0.46254, saving model to weights\best_model_louvain.h5
# Epoch 36/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5166 - accuracy: 0.9809 - auc: 0.9994 - precision: 1.0000 - recall: 0.8790 - val_loss: 0.4571 - val_accuracy: 0.9750 - val_auc: 0.9998 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00036: val_loss improved from 0.46254 to 0.45706, saving model to weights\best_model_louvain.h5
# Epoch 37/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5245 - accuracy: 0.9936 - auc: 0.9996 - precision: 1.0000 - recall: 0.8917 - val_loss: 0.4511 - val_accuracy: 0.9750 - val_auc: 0.9998 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00037: val_loss improved from 0.45706 to 0.45107, saving model to weights\best_model_louvain.h5
# Epoch 38/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5085 - accuracy: 0.9745 - auc: 0.9980 - precision: 0.9926 - recall: 0.8535 - val_loss: 0.4452 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00038: val_loss improved from 0.45107 to 0.44517, saving model to weights\best_model_louvain.h5
# Epoch 39/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5064 - accuracy: 0.9682 - auc: 0.9979 - precision: 1.0000 - recall: 0.8790 - val_loss: 0.4397 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00039: val_loss improved from 0.44517 to 0.43973, saving model to weights\best_model_louvain.h5
# Epoch 40/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5115 - accuracy: 0.9873 - auc: 0.9997 - precision: 1.0000 - recall: 0.9108 - val_loss: 0.4347 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00040: val_loss improved from 0.43973 to 0.43466, saving model to weights\best_model_louvain.h5
# Epoch 41/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5052 - accuracy: 0.9745 - auc: 0.9991 - precision: 1.0000 - recall: 0.9236 - val_loss: 0.4295 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00041: val_loss improved from 0.43466 to 0.42949, saving model to weights\best_model_louvain.h5
# Epoch 42/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4920 - accuracy: 0.9936 - auc: 0.9999 - precision: 1.0000 - recall: 0.9045 - val_loss: 0.4245 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.8750
#
# Epoch 00042: val_loss improved from 0.42949 to 0.42452, saving model to weights\best_model_louvain.h5
# Epoch 43/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4762 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9427 - val_loss: 0.4191 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9000
#
# Epoch 00043: val_loss improved from 0.42452 to 0.41911, saving model to weights\best_model_louvain.h5
# Epoch 44/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4953 - accuracy: 0.9809 - auc: 0.9991 - precision: 1.0000 - recall: 0.9045 - val_loss: 0.4135 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9000
#
# Epoch 00044: val_loss improved from 0.41911 to 0.41354, saving model to weights\best_model_louvain.h5
# Epoch 45/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4854 - accuracy: 0.9873 - auc: 0.9991 - precision: 1.0000 - recall: 0.9299 - val_loss: 0.4080 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9250
#
# Epoch 00045: val_loss improved from 0.41354 to 0.40797, saving model to weights\best_model_louvain.h5
# Epoch 46/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5071 - accuracy: 0.9745 - auc: 0.9973 - precision: 0.9792 - recall: 0.8981 - val_loss: 0.4029 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9500
#
# Epoch 00046: val_loss improved from 0.40797 to 0.40286, saving model to weights\best_model_louvain.h5
# Epoch 47/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4738 - accuracy: 0.9936 - auc: 0.9998 - precision: 1.0000 - recall: 0.8981 - val_loss: 0.3981 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9500
#
# Epoch 00047: val_loss improved from 0.40286 to 0.39808, saving model to weights\best_model_louvain.h5
# Epoch 48/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4612 - accuracy: 0.9745 - auc: 0.9976 - precision: 1.0000 - recall: 0.8854 - val_loss: 0.3935 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00048: val_loss improved from 0.39808 to 0.39349, saving model to weights\best_model_louvain.h5
# Epoch 49/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4473 - accuracy: 0.9936 - auc: 0.9997 - precision: 1.0000 - recall: 0.9363 - val_loss: 0.3891 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00049: val_loss improved from 0.39349 to 0.38906, saving model to weights\best_model_louvain.h5
# Epoch 50/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4739 - accuracy: 0.9682 - auc: 0.9984 - precision: 1.0000 - recall: 0.9045 - val_loss: 0.3847 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00050: val_loss improved from 0.38906 to 0.38473, saving model to weights\best_model_louvain.h5
# Epoch 51/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4424 - accuracy: 0.9873 - auc: 0.9995 - precision: 1.0000 - recall: 0.9236 - val_loss: 0.3808 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00051: val_loss improved from 0.38473 to 0.38077, saving model to weights\best_model_louvain.h5
# Epoch 52/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4687 - accuracy: 0.9936 - auc: 0.9994 - precision: 0.9928 - recall: 0.8790 - val_loss: 0.3765 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00052: val_loss improved from 0.38077 to 0.37655, saving model to weights\best_model_louvain.h5
# Epoch 53/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4775 - accuracy: 0.9936 - auc: 0.9997 - precision: 1.0000 - recall: 0.9108 - val_loss: 0.3721 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00053: val_loss improved from 0.37655 to 0.37209, saving model to weights\best_model_louvain.h5
# Epoch 54/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4580 - accuracy: 1.0000 - auc: 0.9999 - precision: 1.0000 - recall: 0.8981 - val_loss: 0.3678 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00054: val_loss improved from 0.37209 to 0.36776, saving model to weights\best_model_louvain.h5
# Epoch 55/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4304 - accuracy: 0.9936 - auc: 0.9999 - precision: 1.0000 - recall: 0.9490 - val_loss: 0.3632 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00055: val_loss improved from 0.36776 to 0.36321, saving model to weights\best_model_louvain.h5
# Epoch 56/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4320 - accuracy: 0.9936 - auc: 0.9999 - precision: 1.0000 - recall: 0.9172 - val_loss: 0.3582 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00056: val_loss improved from 0.36321 to 0.35821, saving model to weights\best_model_louvain.h5
# Epoch 57/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4640 - accuracy: 0.9745 - auc: 0.9983 - precision: 1.0000 - recall: 0.8981 - val_loss: 0.3530 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00057: val_loss improved from 0.35821 to 0.35297, saving model to weights\best_model_louvain.h5
# Epoch 58/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4439 - accuracy: 1.0000 - auc: 0.9998 - precision: 1.0000 - recall: 0.9236 - val_loss: 0.3481 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00058: val_loss improved from 0.35297 to 0.34806, saving model to weights\best_model_louvain.h5
# Epoch 59/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4202 - accuracy: 0.9936 - auc: 0.9994 - precision: 1.0000 - recall: 0.9490 - val_loss: 0.3433 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00059: val_loss improved from 0.34806 to 0.34326, saving model to weights\best_model_louvain.h5
# Epoch 60/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4410 - accuracy: 0.9873 - auc: 0.9989 - precision: 0.9929 - recall: 0.8917 - val_loss: 0.3387 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00060: val_loss improved from 0.34326 to 0.33871, saving model to weights\best_model_louvain.h5
# Epoch 61/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4288 - accuracy: 0.9809 - auc: 0.9994 - precision: 0.9932 - recall: 0.9299 - val_loss: 0.3348 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00061: val_loss improved from 0.33871 to 0.33479, saving model to weights\best_model_louvain.h5
# Epoch 62/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4204 - accuracy: 0.9873 - auc: 0.9997 - precision: 1.0000 - recall: 0.9299 - val_loss: 0.3311 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00062: val_loss improved from 0.33479 to 0.33108, saving model to weights\best_model_louvain.h5
# Epoch 63/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4186 - accuracy: 0.9936 - auc: 0.9999 - precision: 1.0000 - recall: 0.9427 - val_loss: 0.3274 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00063: val_loss improved from 0.33108 to 0.32741, saving model to weights\best_model_louvain.h5
# Epoch 64/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4214 - accuracy: 0.9745 - auc: 0.9992 - precision: 1.0000 - recall: 0.9172 - val_loss: 0.3239 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00064: val_loss improved from 0.32741 to 0.32387, saving model to weights\best_model_louvain.h5
# Epoch 65/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4197 - accuracy: 0.9809 - auc: 0.9999 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.3205 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00065: val_loss improved from 0.32387 to 0.32055, saving model to weights\best_model_louvain.h5
# Epoch 66/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3978 - accuracy: 0.9873 - auc: 0.9996 - precision: 1.0000 - recall: 0.9363 - val_loss: 0.3170 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00066: val_loss improved from 0.32055 to 0.31698, saving model to weights\best_model_louvain.h5
# Epoch 67/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4056 - accuracy: 0.9745 - auc: 0.9996 - precision: 1.0000 - recall: 0.9363 - val_loss: 0.3131 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00067: val_loss improved from 0.31698 to 0.31310, saving model to weights\best_model_louvain.h5
# Epoch 68/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3763 - accuracy: 0.9936 - auc: 0.9998 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.3092 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00068: val_loss improved from 0.31310 to 0.30920, saving model to weights\best_model_louvain.h5
# Epoch 69/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4088 - accuracy: 0.9809 - auc: 0.9996 - precision: 1.0000 - recall: 0.9236 - val_loss: 0.3049 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00069: val_loss improved from 0.30920 to 0.30494, saving model to weights\best_model_louvain.h5
# Epoch 70/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3714 - accuracy: 0.9873 - auc: 0.9998 - precision: 1.0000 - recall: 0.9745 - val_loss: 0.3006 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00070: val_loss improved from 0.30494 to 0.30060, saving model to weights\best_model_louvain.h5
# Epoch 71/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3832 - accuracy: 0.9873 - auc: 0.9997 - precision: 1.0000 - recall: 0.9108 - val_loss: 0.2960 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00071: val_loss improved from 0.30060 to 0.29604, saving model to weights\best_model_louvain.h5
# Epoch 72/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3625 - accuracy: 0.9809 - auc: 0.9994 - precision: 0.9932 - recall: 0.9363 - val_loss: 0.2920 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00072: val_loss improved from 0.29604 to 0.29199, saving model to weights\best_model_louvain.h5
# Epoch 73/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3680 - accuracy: 0.9873 - auc: 0.9999 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.2884 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00073: val_loss improved from 0.29199 to 0.28840, saving model to weights\best_model_louvain.h5
# Epoch 74/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3705 - accuracy: 0.9936 - auc: 1.0000 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.2852 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00074: val_loss improved from 0.28840 to 0.28524, saving model to weights\best_model_louvain.h5
# Epoch 75/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3649 - accuracy: 1.0000 - auc: 0.9999 - precision: 1.0000 - recall: 0.9427 - val_loss: 0.2825 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00075: val_loss improved from 0.28524 to 0.28254, saving model to weights\best_model_louvain.h5
# Epoch 76/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3760 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9618 - val_loss: 0.2799 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00076: val_loss improved from 0.28254 to 0.27986, saving model to weights\best_model_louvain.h5
# Epoch 77/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3546 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9363 - val_loss: 0.2773 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00077: val_loss improved from 0.27986 to 0.27731, saving model to weights\best_model_louvain.h5
# Epoch 78/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3737 - accuracy: 0.9936 - auc: 0.9998 - precision: 0.9934 - recall: 0.9618 - val_loss: 0.2750 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00078: val_loss improved from 0.27731 to 0.27504, saving model to weights\best_model_louvain.h5
# Epoch 79/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3643 - accuracy: 0.9809 - auc: 0.9992 - precision: 0.9934 - recall: 0.9554 - val_loss: 0.2723 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00079: val_loss improved from 0.27504 to 0.27233, saving model to weights\best_model_louvain.h5
# Epoch 80/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3754 - accuracy: 0.9936 - auc: 0.9997 - precision: 1.0000 - recall: 0.9299 - val_loss: 0.2694 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00080: val_loss improved from 0.27233 to 0.26941, saving model to weights\best_model_louvain.h5
# Epoch 81/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3301 - accuracy: 0.9873 - auc: 0.9999 - precision: 1.0000 - recall: 0.9809 - val_loss: 0.2666 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 1.0000 - val_recall: 0.9750
#
# Epoch 00081: val_loss improved from 0.26941 to 0.26659, saving model to weights\best_model_louvain.h5
# Epoch 82/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3662 - accuracy: 0.9936 - auc: 0.9997 - precision: 0.9932 - recall: 0.9363 - val_loss: 0.2637 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00082: val_loss improved from 0.26659 to 0.26369, saving model to weights\best_model_louvain.h5
# Epoch 83/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3478 - accuracy: 0.9873 - auc: 0.9998 - precision: 1.0000 - recall: 0.9745 - val_loss: 0.2612 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00083: val_loss improved from 0.26369 to 0.26123, saving model to weights\best_model_louvain.h5
# Epoch 84/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3470 - accuracy: 0.9936 - auc: 0.9999 - precision: 1.0000 - recall: 0.9554 - val_loss: 0.2589 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00084: val_loss improved from 0.26123 to 0.25886, saving model to weights\best_model_louvain.h5
# Epoch 85/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3679 - accuracy: 0.9873 - auc: 0.9993 - precision: 1.0000 - recall: 0.9618 - val_loss: 0.2565 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00085: val_loss improved from 0.25886 to 0.25651, saving model to weights\best_model_louvain.h5
# Epoch 86/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3353 - accuracy: 0.9809 - auc: 0.9997 - precision: 1.0000 - recall: 0.9427 - val_loss: 0.2544 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00086: val_loss improved from 0.25651 to 0.25437, saving model to weights\best_model_louvain.h5
# Epoch 87/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3460 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9745 - val_loss: 0.2518 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00087: val_loss improved from 0.25437 to 0.25182, saving model to weights\best_model_louvain.h5
# Epoch 88/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3392 - accuracy: 0.9936 - auc: 0.9997 - precision: 1.0000 - recall: 0.9490 - val_loss: 0.2486 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00088: val_loss improved from 0.25182 to 0.24862, saving model to weights\best_model_louvain.h5
# Epoch 89/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3000 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9809 - val_loss: 0.2455 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00089: val_loss improved from 0.24862 to 0.24547, saving model to weights\best_model_louvain.h5
# Epoch 90/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3288 - accuracy: 0.9809 - auc: 0.9991 - precision: 0.9934 - recall: 0.9618 - val_loss: 0.2423 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00090: val_loss improved from 0.24547 to 0.24227, saving model to weights\best_model_louvain.h5
# Epoch 91/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3091 - accuracy: 0.9873 - auc: 0.9997 - precision: 0.9934 - recall: 0.9618 - val_loss: 0.2390 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00091: val_loss improved from 0.24227 to 0.23901, saving model to weights\best_model_louvain.h5
# Epoch 92/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3261 - accuracy: 0.9936 - auc: 0.9998 - precision: 1.0000 - recall: 0.9745 - val_loss: 0.2356 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00092: val_loss improved from 0.23901 to 0.23558, saving model to weights\best_model_louvain.h5
# Epoch 93/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3329 - accuracy: 0.9873 - auc: 0.9999 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.2322 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00093: val_loss improved from 0.23558 to 0.23217, saving model to weights\best_model_louvain.h5
# Epoch 94/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3189 - accuracy: 0.9936 - auc: 0.9998 - precision: 0.9934 - recall: 0.9554 - val_loss: 0.2293 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00094: val_loss improved from 0.23217 to 0.22935, saving model to weights\best_model_louvain.h5
# Epoch 95/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3148 - accuracy: 0.9809 - auc: 0.9997 - precision: 1.0000 - recall: 0.9745 - val_loss: 0.2271 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00095: val_loss improved from 0.22935 to 0.22706, saving model to weights\best_model_louvain.h5
# Epoch 96/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3178 - accuracy: 0.9936 - auc: 0.9994 - precision: 0.9934 - recall: 0.9618 - val_loss: 0.2250 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00096: val_loss improved from 0.22706 to 0.22501, saving model to weights\best_model_louvain.h5
# Epoch 97/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2994 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9936 - val_loss: 0.2230 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00097: val_loss improved from 0.22501 to 0.22296, saving model to weights\best_model_louvain.h5
# Epoch 98/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3156 - accuracy: 0.9936 - auc: 1.0000 - precision: 1.0000 - recall: 0.9809 - val_loss: 0.2216 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00098: val_loss improved from 0.22296 to 0.22165, saving model to weights\best_model_louvain.h5
# Epoch 99/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3213 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9682 - val_loss: 0.2208 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00099: val_loss improved from 0.22165 to 0.22079, saving model to weights\best_model_louvain.h5
# Epoch 100/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2846 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9936 - val_loss: 0.2201 - val_accuracy: 0.9750 - val_auc: 0.9997 - val_precision: 0.9750 - val_recall: 0.9750
#
# Epoch 00100: val_loss improved from 0.22079 to 0.22014, saving model to weights\best_model_louvain.h5
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.92      1.00      0.96        12
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.97        40
#    macro avg       0.97      0.99      0.98        40
# weighted avg       0.98      0.97      0.98        40
#
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2201 - accuracy: 0.9750 - auc: 0.9997 - precision: 0.9750 - recall: 0.9750
# Memory Usage: 9.77 Mb
# Required Time: 1.625 sec

# %%
# thr=0.95
# n_genes = math.ceil((1 - thr) * adata.var.shape[0])


# t=time.process_time()
# tracemalloc.start()
# # Run SHAP to identify marker genes
# selected_genes, selected_genes_dict = smash.run_shap(adata, group_by='louvain', pct=0.5, restrict_top=("global", n_genes))

# current, peak = tracemalloc.get_traced_memory()
# print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
# print(f'Required Time: {time.process_time() - t} sec')
# tracemalloc.stop()

# %% [markdown]
# # Cluster Reconstructed Dataset (SMaSH)

# %%
print(f'\nTotal Marker genes ({len(selected_genes)}): ')

X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

# expression data with only marker genes
expr_data = expr_data.loc[selected_genes]
print(expr_data.shape)

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)

rc_pd = pd.DataFrame(
    rcdata.X.T,
    index=rcdata.var_names,
    columns=rcdata.obs_names
)

if "X_pca" not in rcdata.obsm and "neighbors" not in rcdata.uns:
    sc.pp.pca(rcdata, n_comps=min(50, rcdata.shape[0], rcdata.shape[1]))
    sc.pp.neighbors(rcdata, n_pcs=min(50, rcdata.shape[0], rcdata.shape[1]))

smash_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.07)
# Out:
# Total Marker genes (1000):
# (1000, 197)
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 197 × 1000
#     obs: 'cluster'
#
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.9629
# Normalized Mutual Information (NMI): 0.9454
# Silhouette Score: 0.1971

# %% [markdown]
# # Cosg Marker Genes

# %%
import cosg as cosg
import importlib
importlib.reload(cosg)
# Out:
# <module 'cosg' from 'D:\\FYDP\\Implementation\\Notebooks\\python3.8\\lib\\site-packages\\cosg\\__init__.py'>

# %%
t=time.process_time()
tracemalloc.start()

cosg.cosg(adata,
    key_added='cosg',
        mu=1,
        n_genes_user=300,
               groupby='louvain')

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# **finished identifying marker genes by COSG**
# Memory Usage: 22.11 Mb
# Required Time: 0.078125 sec

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 197 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'compartment_colors', 'donor_id_colors', 'leiden', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap', 'cluster_colors', 'louvain', 'louvain_colors', 'hvg', 'cosg'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'

# %%
# cosg_marker_genes = np.unique(np.array(adata.uns['cosg']['names'])).tolist()
cosg_marker_genes = pd.unique(pd.DataFrame(adata.uns['cosg']['names']).values.ravel()).tolist()

# %% [markdown]
# # Cluster Reconstructed Dataset (Cosg)

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

cosg_expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

cosg_expr_data = cosg_expr_data.loc[cosg_marker_genes]
print(cosg_expr_data.shape)

cgdata = sc.AnnData(X=cosg_expr_data.values.T)
cgdata.var_names = cosg_expr_data.index
cgdata.obs_names = cosg_expr_data.columns
cgdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(cgdata)
# Out:
# (900, 197)
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 197 × 900
#     obs: 'cluster'

# %%
if "X_pca" not in cgdata.obsm and "neighbors" not in cgdata.uns:
  sc.pp.pca(cgdata, n_comps=50)
  sc.pp.neighbors(cgdata, n_pcs=50)
cosg_sil_scores = cluster_with_louvain(cgdata, epochs=1, resolution=0.078 )
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.9813
# Normalized Mutual Information (NMI): 0.9688
# Silhouette Score: 0.3291

# %% [markdown]
# # Unified Marker Genes (CellTICS + COSG+ SMaSH)

# %%
silhouette_scores = {
    'celltics': cellTICS_sil_scores,
    'cosg': cosg_sil_scores,
    'smash': smash_sil_scores
}
print('silhouette scores: ', silhouette_scores)
methods_importance = calculate_importance(silhouette_scores)
print('methods_importance: ', methods_importance)
# Out:
# silhouette scores:  {'celltics': [0.20839709], 'cosg': [0.32908425], 'smash': [0.19705097]}
# methods_importance:  {'celltics': 0.2837139866492686, 'cosg': 0.4480187490354991, 'smash': 0.2682672643152323}

# %%
# getting genes with highest weights
# methods_importance = {
#     'celltics': 0.349,
#     'cosg': 0.382,
#     'smash': 0.267
# }
UMG = pd.unique(score_marker_genes(high_markers,cosg_marker_genes,selected_genes, methods_importance, p=0.95))
# Out:
# total genes: 9150
# selected genes: 8692

# %%
len(UMG)
# Out:
# 8692

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

exp_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

exp_data = exp_data.loc[UMG]

ccdata = sc.AnnData(X=exp_data.values.T)
ccdata.var_names = exp_data.index
ccdata.obs_names = exp_data.columns
ccdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(ccdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 197 × 8692
#     obs: 'cluster'

# %%
if "X_pca" not in ccdata.obsm and "neighbors" not in ccdata.uns:
  sc.pp.pca(ccdata, n_comps=50)
  sc.pp.neighbors(ccdata, n_pcs=50)
cluster_with_louvain(ccdata, epochs=1, resolution=0.07)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.9447
# Normalized Mutual Information (NMI): 0.9250
# Silhouette Score: 0.2073
# [0.20727408]
