# %% [markdown]
# # Installation and Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import math
import pandas as pd
import scanpy as sc
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, silhouette_score
import time
import tracemalloc
from tensorflow.keras.regularizers import l2

# %%
import scvi
# Out:
# Global seed set to 0

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# scanpy==1.9.6 anndata==0.9.2 umap==0.5.7 numpy==1.19.5 scipy==1.10.1 pandas==1.4.4 scikit-learn==1.3.2 statsmodels==0.14.1 igraph==0.11.8 louvain==0.8.2 pynndescent==0.5.13

# %% [markdown]
# # Defined Methods

# %% [markdown]
# ## Data Preprocessing

# %%
def data_init_x(path):
    print("\n==========================  Data Initialization  =================================\n")
    
    adata = sc.read_h5ad(path)

    print("Loaded Dataset Structure (preview 10×10):")

    # SAFE preview for sparse matrix
    X_preview = adata.X[:10, :10]
    if sp.issparse(X_preview):
        X_preview = X_preview.toarray()

    print(
        pd.DataFrame(
            X_preview,
            index=adata.obs.index[:10],
            columns=adata.var.index[:10]
        )
    )

    print("\nAnnData summary:")
    print(adata)

    print("\nTotal Clusters:")
    print(np.unique(adata.obs["cluster"]))

    print("\nCluster labels (first 20):")
    print(adata.obs["cluster"].head(20).values)

    # PCA + neighbors + UMAP
    sc.pp.pca(adata, n_comps=50)
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)

    print("\nExisting Cluster (UMAP)")
    sc.pl.umap(adata, color="cluster")

    return adata

# %%
def data_init(path):
    print("\n==========================  Data Initialization  =================================\n")
    data = pd.read_csv(path, index_col=0).astype('float64')
    clusters = data.columns
    clusters = [int(x) for x in [float(x) for x in clusters]]
    adata = sc.AnnData(X=(data.values.T))
    adata.var_names = data.index
    adata.obs_names = [f"cell-{i}" for i in range(1, len(clusters) + 1)]
    adata.obs["cluster"] = clusters
    print("Loaded Dataset Structure: ")
    print((pd.DataFrame(adata.X, index=adata.obs.index, columns=adata.var.index)).iloc[:10, :10])
    print(adata)
    print(f'Total Clusters: \n{np.unique(adata.obs["cluster"])}')
    print(f'Clusters: \n{adata.obs["cluster"]}')
    sc.pp.pca(adata, n_comps=50) 
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)
    print("Existing Cluster")
    sc.pl.umap(adata, color='cluster')
    return adata

# %%
def data_processing(adata):
  print("\n==========================  Data Processing  =================================\n")
  sc.pp.filter_cells(adata, min_genes=200)
  sc.pp.filter_genes(adata, min_cells=3)
  sc.pp.normalize_per_cell(adata)
  sc.pp.log1p(adata, copy=True)
  return adata

# %% [markdown]
# ## Remove Batch Effects

# %%
def remove_batch_effect(adata, batch_key='batch', n_pcs=20, method='harmony'):
    
    if batch_key not in adata.obs:
        raise KeyError(f"Batch key '{batch_key}' not found in adata.obs")
    
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    
    sc.pp.highly_variable_genes(adata, flavor='cell_ranger', n_top_genes=2000)
    adata = adata[:, adata.var['highly_variable']].copy()
    sc.pp.scale(adata, max_value=10)
    
    sc.tl.pca(adata, n_comps=n_pcs, svd_solver='arpack')
    
    if method.lower() == 'harmony':
        ho = hm.run_harmony(adata.obsm['X_pca'], adata.obs, batch_key)
        adata.obsm['X_pca_harmony'] = ho.Z_corr
        sc.pp.neighbors(adata, use_rep='X_pca_harmony')
    elif method.lower() == 'bbknn':
        sce.pp.bbknn(adata, batch_key=batch_key, n_pcs=n_pcs)
    else:
        raise ValueError("Method must be 'harmony' or 'bbknn'.")
    
    sc.tl.umap(adata)

# %% [markdown]
# ## Denoising

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import scanpy as sc
import numpy as np

def Denoise(adata):
    
    # Step 1: Load and preprocess data
    X = adata.X  # Assuming adata.X is in sparse format
    X = X.toarray() if hasattr(X, "toarray") else X  # Convert to dense if sparse
    
    # Normalize and scale data
    X = sc.pp.log1p(X, copy=True)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    # Step 2: Add sparse noise to mimic biological dropout
    def add_sparse_noise(data, dropout_rate=0.1):
        """
        Adds sparse dropout noise to mimic missing data in scRNA-seq.
        """
        noisy_data = data.copy()
        mask = np.random.binomial(1, dropout_rate, size=data.shape)  # Create dropout mask
        noisy_data[mask == 1] = 0  # Set selected values to zero
        return noisy_data
    
    X_noisy = add_sparse_noise(X)
    
    # Step 3: Define sparse-aware denoising autoencoder
    input_dim = X.shape[1]
    
    # Encoder
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(512, activation='relu')(input_layer)
    encoded = BatchNormalization()(encoded)
    encoded = Dropout(0.2)(encoded)
    latent_space = Dense(128, activation='relu')(encoded)
    
    # Decoder
    decoded = Dense(512, activation='relu')(latent_space)
    decoded = BatchNormalization()(decoded)
    decoded = Dropout(0.2)(decoded)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    # Autoencoder model
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    
    # Custom sparse-aware loss
    def sparse_mse(y_true, y_pred):
        """
        Custom loss to preserve zeros and penalize large changes to nonzero values.
        """
        mask = tf.cast(tf.equal(y_true, 0.0), tf.float32)  # Mask for zeros in original data
        nonzero_loss = tf.reduce_mean(tf.square((1 - mask) * (y_true - y_pred)))  # Penalize changes to nonzeros
        zero_loss = tf.reduce_mean(tf.square(mask * y_pred))  # Penalize predicted values where true value is zero
        return nonzero_loss + 0.1 * zero_loss  # Combine losses with weight for zero preservation
    
    # Compile the model
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                        loss=sparse_mse,
                        metrics=['mae'])
    
    # Step 4: Train the model
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
    X_noisy_train, X_noisy_val = train_test_split(X_noisy, test_size=0.2, random_state=42)
    
    history = autoencoder.fit(
        X_noisy_train, X_train,
        validation_data=(X_noisy_val, X_val),
        epochs=200,
        batch_size=256,
        shuffle=True,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
        ]
    )
    
    # Step 5: Denoise the data
    X_denoised = autoencoder.predict(X_noisy)
    
    # Save the denoised output
    adata.X = scaler.inverse_transform(X_denoised)  # Inverse scaling
    return adata

# %% [markdown]
# ## Clustering

# %%
def cluster_with_louvain(adata, epochs, resolution=2.5):
  print("\n========================== Clustering With Louvain =================================\n")
  # if "X_pca" not in adata.obsm and "neighbors" not in adata.uns:
  sc.pp.pca(adata)
  sc.pp.neighbors(adata)
  sil_scores = []

  for i in range(0, epochs):
    sc.tl.louvain(adata, resolution)

    print(f"\nClustering epoch {i+1} ------------------")
    ari = adjusted_rand_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Adjusted Rand Index (ARI): {ari:.4f}")

    nmi = normalized_mutual_info_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Normalized Mutual Information (NMI): {nmi:.4f}")

    X = adata.obsm["X_pca"]
    sil_score = silhouette_score(X, adata.obs['louvain'])
    sil_scores.append(sil_score)
    print(f"Silhouette Score: {sil_score:.4f}\n")

      
  sc.tl.umap(adata)
  sc.pl.umap(adata, color='louvain')
  return sil_scores

# %% [markdown]
# ## Identify Marker Gene

# %% [markdown]
# ### CellTICS

# %%
# Define fphi - High markers
def fphi(x):

    # Step 1: Normalized by max value (x + 1) / (max(x) + 1)
    normalized = (x + 1).div(x.max(axis=1) + 1, axis=0)

    # Step 2: Suppression factor (zt)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)

    # Step 3: phi values after applying suppression factor
    zp = normalized.mul(zt, axis=0)

    return zp

# Define frho - Low markers
def frho(x):
    # Step 1: Normalized by min value (1 / (x + 1)) * (min(x) + 1)
    normalized = (1 / (x + 1)).mul(x.min(axis=1) + 1, axis=0)

    # Step 2: Enhancement factor (zt)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)

    # Step 3: rho values after applying enhancement factor
    zp = normalized.mul(zt, axis=0)

    return zp



# thr1 -> high marker quantile | thr2 -> Low marker quantile
def CellTICS_marker_genes(adata, thr1=0.95, thr2=0.9):
  print("\n====================== Identify Marker Gene With CellTICS ============================\n")
  print("Expression Values of Genes: \n")
  expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
  louvain_labels = pd.Series(adata.obs['louvain'].values, index=adata.obs_names)
  print(expr_data.iloc[:10, :10])
  print(adata)

  print("\nAverage the cell expr data according to the clusters:\n")
  avg_expr_data = expr_data.T.groupby(louvain_labels).mean().T
  print(avg_expr_data.iloc[:10, :])

  phi = fphi(avg_expr_data)
  rho = frho(avg_expr_data)


  gnm = phi.index.values 
  ctpnm = phi.columns.values


  phi = np.array(phi)
  rho = np.array(rho)


  nummkg1 = math.ceil((1 - thr1) * phi.shape[0]) 
  nummkg2 = math.ceil((1 - thr2) * phi.shape[0]) 


  alpha = [] 
  beta = []
  for i in range(0, phi.shape[1]):
      alpha.append(np.quantile(phi[:, i], thr1))
      beta.append(np.quantile(rho[:, i], thr2))



  mkh = [] 
  mkl = [] 
  for i in range(0, phi.shape[1]):
      high_markers = gnm[phi[:, i] >= alpha[i]][0:nummkg1]
      low_markers = gnm[rho[:, i] >= beta[i]][0:nummkg2]
      mkh = np.concatenate([mkh, high_markers], axis=0) if len(mkh) > 0 else high_markers
      mkl = np.concatenate([mkl, low_markers], axis=0) if len(mkl) > 0 else low_markers


  mkh = mkh.reshape(nummkg1, phi.shape[1])
  mkl = mkl.reshape(nummkg2, rho.shape[1])
  mkh = pd.DataFrame(mkh, columns=ctpnm)
  mkl = pd.DataFrame(mkl, columns=ctpnm)

  print("\nHigh Marker Genes for each cluster/type: \n")
  print(mkh.iloc[:10, :])

  print("\nLow Marker Genes for each cluster/type: \n")
  print(mkl.iloc[:10, :])

  return mkh, mkl

# %%
# getting list of all high and low marker genes
def get_unique_marker_genes(high_markers):
  unique_high_markers = high_markers
  unique_high_markers = pd.unique(unique_high_markers.values.ravel()).tolist()
  print(f"\nTotal Unique High Marker Gene for all together {len(unique_high_markers)}: ")
  return unique_high_markers

# %% [markdown]
# ## Calculate Importance

# %%
def calculate_importance(silhouette_scores):
    avg_scores = {k: sum(v) / len(v) for k, v in silhouette_scores.items()}
    
    total = sum(avg_scores.values())
    return {k: v / total for k, v in avg_scores.items()}

# %% [markdown]
# ## Unified Marker Genes (Weight Based)

# %%
from collections import defaultdict

def score_marker_genes(celltics_genes, smash_genes, cosg_genes, importance, p=1.0):
    
    gene_weights = defaultdict(float)
    
    for gene in celltics_genes:
        gene_weights[gene] += importance['celltics']
        
    for gene in smash_genes:
        gene_weights[gene] += importance['smash']
        
    for gene in cosg_genes:
        gene_weights[gene] += importance['cosg']
    
    selected_genes = sorted(gene_weights.items(), key=lambda x: x[1], reverse=True) # selecting genes with highest weight

    print(f'total genes: {len(selected_genes)}')
    
    top_n = int(len(selected_genes) * p)

    print(f'selected genes: {top_n}')
    
    return [gene for gene, weight in selected_genes[:top_n]]

# %% [markdown]
# # Implementations____________

# %%
import scipy.sparse as sp

# %%
dataset_path = "new_processed.h5ad"

adata = data_init_x(dataset_path)

# adata = data_processing(adata)

# adata = Denoise(adata)

# adata = sc.read_h5ad("new_processed.h5ad")

sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, n_pcs=50)
sc.tl.umap(adata)
# Out:
# ==========================  Data Initialization  =================================
#
# Loaded Dataset Structure (preview 10×10):
#          ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  ENSG00000001084  ENSG00000001167
# cell-1          0.284197         0.002777         0.183665         0.039405         0.069569         0.000926         0.025675         0.053671         0.083232         0.145264
# cell-2          0.283562         0.002764         0.183518         0.039005         0.069001         0.000926         0.023489         0.053671         0.086255         0.145233
# cell-3          0.283457         0.002759         0.183498         0.039669         0.071523         0.000926         0.021853         0.053671         0.098245         0.145228
# cell-4          0.283550         0.002761         0.183464         0.040247         0.068943         0.000926         0.033397         0.053671         0.097211         0.145227
# cell-5          0.283652         0.002790         0.183529         0.039055         0.067205         0.000926         0.022514         0.053671         0.068482         0.145235
# cell-6          0.283689         0.002760         0.184001         0.038426         0.068551         0.000926         0.013431         0.053670         0.089868         0.145238
# cell-7          0.284338         0.002779         0.183610         0.039776         0.071323         0.000926         0.031665         0.053671         0.090794         0.145279
# cell-8          0.283802         0.002766         0.183615         0.039336         0.068485         0.000926         0.020804         0.053671         0.088918         0.145238
# cell-9          0.283743         0.002764         0.183591         0.038863         0.069487         0.000926         0.019862         0.053671         0.091349         0.145240
# cell-10         0.283523         0.002760         0.183481         0.038506         0.068115         0.000926         0.016073         0.053671         0.095993         0.145228
#
# AnnData summary:
# AnnData object with n_obs × n_vars = 7276 × 42169
#     obs: 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#
# Total Clusters:
# [0 1 2 3 4]
#
# Cluster labels (first 20):
# [4 4 4 4 4 4 4 4 4 4 4 2 1 2 2 2 0 1 2 1]
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:12)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:23)
#
# Existing Cluster (UMAP)
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:18)

# %% [markdown]
# # CellTICS Marker Genes

# %%
# adata.write_h5ad("new/new1-processed.h5ad")

# %%
cluster_with_louvain(adata, epochs=1, resolution=0.05)
t=time.process_time()
tracemalloc.start()

high_markers, low_markers = CellTICS_marker_genes(adata, thr1=0.85, thr2= 0.95)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()


high_markers = get_unique_marker_genes(high_markers)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:07)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 5 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:01)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.4346
# Normalized Mutual Information (NMI): 0.5521
# Silhouette Score: 0.4767
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:16)
# ====================== Identify Marker Gene With CellTICS ============================
#
# Expression Values of Genes:
#
#                    cell-1    cell-2    cell-3    cell-4    cell-5    cell-6    cell-7    cell-8    cell-9   cell-10
# ENSG00000000003  0.284197  0.283562  0.283457  0.283550  0.283652  0.283689  0.284338  0.283802  0.283743  0.283523
# ENSG00000000005  0.002777  0.002764  0.002759  0.002761  0.002790  0.002760  0.002779  0.002766  0.002764  0.002760
# ENSG00000000419  0.183665  0.183518  0.183498  0.183464  0.183529  0.184001  0.183610  0.183615  0.183591  0.183481
# ENSG00000000457  0.039405  0.039005  0.039669  0.040247  0.039055  0.038426  0.039776  0.039336  0.038863  0.038506
# ENSG00000000460  0.069569  0.069001  0.071523  0.068943  0.067205  0.068551  0.071323  0.068485  0.069487  0.068115
# ENSG00000000938  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926  0.000926
# ENSG00000000971  0.025675  0.023489  0.021853  0.033397  0.022514  0.013431  0.031665  0.020804  0.019862  0.016073
# ENSG00000001036  0.053671  0.053671  0.053671  0.053671  0.053671  0.053670  0.053671  0.053671  0.053671  0.053671
# ENSG00000001084  0.083232  0.086255  0.098245  0.097211  0.068482  0.089868  0.090794  0.088918  0.091349  0.095993
# ENSG00000001167  0.145264  0.145233  0.145228  0.145227  0.145235  0.145238  0.145279  0.145238  0.145240  0.145228
# AnnData object with n_obs × n_vars = 7276 × 42169
#     obs: 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#
# Average the cell expr data according to the clusters:
#
#                         0         1         2         3         4
# ENSG00000000003  0.464335  0.438235  0.283830  0.307424  0.283971
# ENSG00000000005  0.002857  0.003096  0.002880  0.008196  0.002801
# ENSG00000000419  0.185417  0.295273  0.185902  0.260719  0.203485
# ENSG00000000457  0.038298  0.038272  0.104509  0.038812  0.090222
# ENSG00000000460  0.067000  0.067047  0.155737  0.068642  0.201125
# ENSG00000000938  0.001057  0.001199  0.002753  0.001072  0.001276
# ENSG00000000971  0.002996  0.002919  0.006454  0.002750  0.006053
# ENSG00000001036  0.005220  0.005384  0.009784  0.005226  0.013027
# ENSG00000001084  0.013085  0.017110  0.014815  0.015755  0.055699
# ENSG00000001167  0.146183  0.156571  0.221031  0.161810  0.173287
#
# High Marker Genes for each cluster/type:
#
#                  0                1                2                3                4
# 0  ENSG00000000003  ENSG00000000460  ENSG00000001629  ENSG00000001631  ENSG00000002330
# 1  ENSG00000002549  ENSG00000002746  ENSG00000002834  ENSG00000003056  ENSG00000003147
# 2  ENSG00000003509  ENSG00000004455  ENSG00000004478  ENSG00000004487  ENSG00000004534
# 3  ENSG00000004776  ENSG00000004779  ENSG00000004809  ENSG00000004838  ENSG00000004897
# 4  ENSG00000005075  ENSG00000005175  ENSG00000005189  ENSG00000005194  ENSG00000005206
# 5  ENSG00000005339  ENSG00000005448  ENSG00000005483  ENSG00000005810  ENSG00000005812
# 6  ENSG00000006125  ENSG00000006282  ENSG00000006453  ENSG00000006459  ENSG00000006576
# 7  ENSG00000006607  ENSG00000006634  ENSG00000006712  ENSG00000006715  ENSG00000006747
# 8  ENSG00000006831  ENSG00000007038  ENSG00000007168  ENSG00000007202  ENSG00000007350
# 9  ENSG00000007392  ENSG00000007402  ENSG00000007545  ENSG00000007944  ENSG00000008018
#
# Low Marker Genes for each cluster/type:
#
#                  0                1                2                3                4
# 0  ENSG00000001629  ENSG00000002746  ENSG00000003147  ENSG00000004478  ENSG00000004487
# 1  ENSG00000004534  ENSG00000004838  ENSG00000004897  ENSG00000005175  ENSG00000005189
# 2  ENSG00000005194  ENSG00000005483  ENSG00000005810  ENSG00000006282  ENSG00000006607
# 3  ENSG00000006634  ENSG00000007392  ENSG00000008018  ENSG00000008083  ENSG00000008256
# 4  ENSG00000008282  ENSG00000008294  ENSG00000008405  ENSG00000008952  ENSG00000009335
# 5  ENSG00000009413  ENSG00000010219  ENSG00000010244  ENSG00000010361  ENSG00000010803
# 6  ENSG00000011028  ENSG00000011114  ENSG00000011258  ENSG00000011405  ENSG00000011454
# 7  ENSG00000013374  ENSG00000013810  ENSG00000015532  ENSG00000015676  ENSG00000020577
# 8  ENSG00000022267  ENSG00000022840  ENSG00000023191  ENSG00000023287  ENSG00000023572
# 9  ENSG00000025796  ENSG00000025800  ENSG00000028310  ENSG00000028839  ENSG00000029725
# Memory Usage: 2347.56 Mb
# Required Time: 4.203125 sec
#
# Total Unique High Marker Gene for all together 6899:

# %% [markdown]
# # Cluster Reconstructed Dataset (CellTICS)

# %%
expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
expr_data = expr_data.loc[high_markers]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7276 × 6899
#     obs: 'cluster'

# %%
# rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

# %%
cellTICS_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.07)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.4331
# Normalized Mutual Information (NMI): 0.5516
# Silhouette Score: 0.4676

# %% [markdown]
# # Smash Marker Genes

# %%
# adata.write_h5ad("new_processed.h5ad")

# %%
# adata = sc.read_h5ad("new_processed.h5ad")

# %%
import os
import smashpy

smash = smashpy.smashpy()

if np.any(np.isnan(adata.X)):
    adata.X = np.nan_to_num(adata.X)

if not os.path.exists('Figures'):
    os.makedirs('Figures')

# smash.DNN(adata, group_by='louvain')
# Out:
#  * Initialising ...
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\smashpy.py:72: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
# import numpy as np
# import scipy.sparse as sp

# clusters = adata.obs["louvain"].unique()

# X_bulk = []
# for c in clusters:
#     idx = adata.obs["louvain"] == c
#     Xc = adata.X[idx]
#     X_bulk.append(Xc.mean(axis=0))

# X_bulk = np.vstack([x.A if sp.issparse(x) else x for x in X_bulk])

# adata_bulk = sc.AnnData(
#     X=X_bulk,
#     var=adata.var.copy(),
#     obs=pd.DataFrame({"cluster": clusters})
# )

# print(adata_bulk)

# %%
# 1. Select HVGs FIRST
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    flavor="cell_ranger"
)

adata_hvg = adata[:, adata.var.highly_variable].copy()

# 2. Train Smash DNN on HVGs
smash.DNN(adata_hvg, group_by='louvain')


t=time.process_time()
tracemalloc.start()

# 3. Run SHAP on the SAME adata_hvg
selected_genes, selected_genes_dict = smash.run_shap(
    adata_hvg,
    group_by='louvain',
    pct=0.2,
    restrict_top=("global", 1000)
)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                64032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 85
# =================================================================
# Total params: 64,837
# Trainable params: 64,741
# Non-trainable params: 96
# _________________________________________________________________
# None
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 59/59 [==============================] - 3s 18ms/step - loss: 1.1907 - accuracy: 0.5852 - auc: 0.8507 - precision: 0.9624 - recall: 0.0792 - val_loss: 1.4997 - val_accuracy: 0.2830 - val_auc: 0.6755 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.49968, saving model to weights\best_model_louvain.h5
# Epoch 2/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.9453 - accuracy: 0.8438 - auc: 0.9732 - precision: 0.9988 - recall: 0.1483 - val_loss: 1.3573 - val_accuracy: 0.5089 - val_auc: 0.7762 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 1.49968 to 1.35734, saving model to weights\best_model_louvain.h5
# Epoch 3/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.7967 - accuracy: 0.9048 - auc: 0.9892 - precision: 0.9958 - recall: 0.3670 - val_loss: 1.1949 - val_accuracy: 0.7816 - val_auc: 0.9089 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 1.35734 to 1.19490, saving model to weights\best_model_louvain.h5
# Epoch 4/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6765 - accuracy: 0.9308 - auc: 0.9930 - precision: 0.9960 - recall: 0.5601 - val_loss: 1.0120 - val_accuracy: 0.8297 - val_auc: 0.9631 - val_precision: 1.0000 - val_recall: 0.1044
#
# Epoch 00004: val_loss improved from 1.19490 to 1.01200, saving model to weights\best_model_louvain.h5
# Epoch 5/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5758 - accuracy: 0.9473 - auc: 0.9956 - precision: 0.9932 - recall: 0.7050 - val_loss: 0.7815 - val_accuracy: 0.9712 - val_auc: 0.9986 - val_precision: 1.0000 - val_recall: 0.2837
#
# Epoch 00005: val_loss improved from 1.01200 to 0.78149, saving model to weights\best_model_louvain.h5
# Epoch 6/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4946 - accuracy: 0.9538 - auc: 0.9967 - precision: 0.9902 - recall: 0.7966 - val_loss: 0.6088 - val_accuracy: 0.9650 - val_auc: 0.9985 - val_precision: 0.9959 - val_recall: 0.6607
#
# Epoch 00006: val_loss improved from 0.78149 to 0.60880, saving model to weights\best_model_louvain.h5
# Epoch 7/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4202 - accuracy: 0.9582 - auc: 0.9977 - precision: 0.9904 - recall: 0.8502 - val_loss: 0.4289 - val_accuracy: 0.9890 - val_auc: 0.9998 - val_precision: 0.9993 - val_recall: 0.9464
#
# Epoch 00007: val_loss improved from 0.60880 to 0.42887, saving model to weights\best_model_louvain.h5
# Epoch 8/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3684 - accuracy: 0.9632 - auc: 0.9979 - precision: 0.9885 - recall: 0.8847 - val_loss: 0.3394 - val_accuracy: 0.9904 - val_auc: 0.9999 - val_precision: 1.0000 - val_recall: 0.9663
#
# Epoch 00008: val_loss improved from 0.42887 to 0.33943, saving model to weights\best_model_louvain.h5
# Epoch 9/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3160 - accuracy: 0.9699 - auc: 0.9985 - precision: 0.9907 - recall: 0.9153 - val_loss: 0.2378 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9801
#
# Epoch 00009: val_loss improved from 0.33943 to 0.23784, saving model to weights\best_model_louvain.h5
# Epoch 10/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2830 - accuracy: 0.9696 - auc: 0.9986 - precision: 0.9870 - recall: 0.9235 - val_loss: 0.2019 - val_accuracy: 0.9924 - val_auc: 0.9998 - val_precision: 0.9979 - val_recall: 0.9835
#
# Epoch 00010: val_loss improved from 0.23784 to 0.20194, saving model to weights\best_model_louvain.h5
# Epoch 11/100
# 59/59 [==============================] - 0s 7ms/step - loss: 0.2432 - accuracy: 0.9761 - auc: 0.9991 - precision: 0.9897 - recall: 0.9442 - val_loss: 0.1714 - val_accuracy: 0.9911 - val_auc: 0.9999 - val_precision: 0.9965 - val_recall: 0.9856
#
# Epoch 00011: val_loss improved from 0.20194 to 0.17141, saving model to weights\best_model_louvain.h5
# Epoch 12/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.2209 - accuracy: 0.9763 - auc: 0.9990 - precision: 0.9855 - recall: 0.9476 - val_loss: 0.1278 - val_accuracy: 0.9938 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9897
#
# Epoch 00012: val_loss improved from 0.17141 to 0.12777, saving model to weights\best_model_louvain.h5
# Epoch 13/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.9758 - auc: 0.9990 - precision: 0.9856 - recall: 0.9522 - val_loss: 0.1581 - val_accuracy: 0.9725 - val_auc: 0.9992 - val_precision: 0.9758 - val_recall: 0.9691
#
# Epoch 00013: val_loss did not improve from 0.12777
# Epoch 14/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9790 - auc: 0.9991 - precision: 0.9862 - recall: 0.9605 - val_loss: 0.1096 - val_accuracy: 0.9890 - val_auc: 0.9998 - val_precision: 0.9958 - val_recall: 0.9808
#
# Epoch 00014: val_loss improved from 0.12777 to 0.10965, saving model to weights\best_model_louvain.h5
# Epoch 15/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9832 - auc: 0.9993 - precision: 0.9903 - recall: 0.9677 - val_loss: 0.0884 - val_accuracy: 0.9924 - val_auc: 1.0000 - val_precision: 0.9945 - val_recall: 0.9904
#
# Epoch 00015: val_loss improved from 0.10965 to 0.08842, saving model to weights\best_model_louvain.h5
# Epoch 16/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.1447 - accuracy: 0.9828 - auc: 0.9994 - precision: 0.9881 - recall: 0.9698 - val_loss: 0.0958 - val_accuracy: 0.9897 - val_auc: 0.9999 - val_precision: 0.9938 - val_recall: 0.9890
#
# Epoch 00016: val_loss did not improve from 0.08842
# Epoch 17/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.1337 - accuracy: 0.9838 - auc: 0.9994 - precision: 0.9886 - recall: 0.9715 - val_loss: 0.0726 - val_accuracy: 0.9883 - val_auc: 0.9999 - val_precision: 0.9924 - val_recall: 0.9842
#
# Epoch 00017: val_loss improved from 0.08842 to 0.07265, saving model to weights\best_model_louvain.h5
# Epoch 18/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.1315 - accuracy: 0.9796 - auc: 0.9993 - precision: 0.9868 - recall: 0.9670 - val_loss: 0.0702 - val_accuracy: 0.9863 - val_auc: 0.9998 - val_precision: 0.9876 - val_recall: 0.9842
#
# Epoch 00018: val_loss improved from 0.07265 to 0.07024, saving model to weights\best_model_louvain.h5
# Epoch 19/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.1167 - accuracy: 0.9821 - auc: 0.9995 - precision: 0.9869 - recall: 0.9727 - val_loss: 0.0691 - val_accuracy: 0.9924 - val_auc: 0.9999 - val_precision: 0.9931 - val_recall: 0.9897
#
# Epoch 00019: val_loss improved from 0.07024 to 0.06910, saving model to weights\best_model_louvain.h5
# Epoch 20/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.1088 - accuracy: 0.9847 - auc: 0.9995 - precision: 0.9882 - recall: 0.9751 - val_loss: 0.0654 - val_accuracy: 0.9863 - val_auc: 0.9999 - val_precision: 0.9924 - val_recall: 0.9842
#
# Epoch 00020: val_loss improved from 0.06910 to 0.06543, saving model to weights\best_model_louvain.h5
# Epoch 21/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.9844 - auc: 0.9996 - precision: 0.9877 - recall: 0.9792 - val_loss: 0.0596 - val_accuracy: 0.9938 - val_auc: 0.9996 - val_precision: 0.9945 - val_recall: 0.9918
#
# Epoch 00021: val_loss improved from 0.06543 to 0.05959, saving model to weights\best_model_louvain.h5
# Epoch 22/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0952 - accuracy: 0.9826 - auc: 0.9996 - precision: 0.9859 - recall: 0.9753 - val_loss: 0.0477 - val_accuracy: 0.9911 - val_auc: 0.9999 - val_precision: 0.9952 - val_recall: 0.9904
#
# Epoch 00022: val_loss improved from 0.05959 to 0.04767, saving model to weights\best_model_louvain.h5
# Epoch 23/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0871 - accuracy: 0.9864 - auc: 0.9996 - precision: 0.9898 - recall: 0.9796 - val_loss: 0.0403 - val_accuracy: 0.9945 - val_auc: 1.0000 - val_precision: 0.9959 - val_recall: 0.9938
#
# Epoch 00023: val_loss improved from 0.04767 to 0.04029, saving model to weights\best_model_louvain.h5
# Epoch 24/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 0.9868 - auc: 0.9997 - precision: 0.9908 - recall: 0.9816 - val_loss: 0.0475 - val_accuracy: 0.9924 - val_auc: 0.9999 - val_precision: 0.9924 - val_recall: 0.9897
#
# Epoch 00024: val_loss did not improve from 0.04029
# Epoch 25/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9857 - auc: 0.9996 - precision: 0.9882 - recall: 0.9820 - val_loss: 0.0395 - val_accuracy: 0.9938 - val_auc: 1.0000 - val_precision: 0.9959 - val_recall: 0.9924
#
# Epoch 00025: val_loss improved from 0.04029 to 0.03949, saving model to weights\best_model_louvain.h5
# Epoch 26/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0782 - accuracy: 0.9856 - auc: 0.9996 - precision: 0.9891 - recall: 0.9808 - val_loss: 0.0413 - val_accuracy: 0.9931 - val_auc: 1.0000 - val_precision: 0.9931 - val_recall: 0.9918
#
# Epoch 00026: val_loss did not improve from 0.03949
# Epoch 27/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.9852 - auc: 0.9996 - precision: 0.9879 - recall: 0.9806 - val_loss: 0.0423 - val_accuracy: 0.9911 - val_auc: 0.9999 - val_precision: 0.9918 - val_recall: 0.9911
#
# Epoch 00027: val_loss did not improve from 0.03949
# Epoch 28/100
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 0.9864 - auc: 0.9995 - precision: 0.9894 - recall: 0.9823 - val_loss: 0.0275 - val_accuracy: 0.9966 - val_auc: 1.0000 - val_precision: 0.9966 - val_recall: 0.9966
#
# Epoch 00028: val_loss improved from 0.03949 to 0.02745, saving model to weights\best_model_louvain.h5
# Epoch 29/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0662 - accuracy: 0.9869 - auc: 0.9996 - precision: 0.9893 - recall: 0.9845 - val_loss: 0.0288 - val_accuracy: 0.9959 - val_auc: 1.0000 - val_precision: 0.9959 - val_recall: 0.9959
#
# Epoch 00029: val_loss did not improve from 0.02745
# Epoch 30/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.9881 - auc: 0.9997 - precision: 0.9901 - recall: 0.9844 - val_loss: 0.0371 - val_accuracy: 0.9924 - val_auc: 0.9999 - val_precision: 0.9931 - val_recall: 0.9924
#
# Epoch 00030: val_loss did not improve from 0.02745
# Epoch 31/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9893 - auc: 0.9998 - precision: 0.9917 - recall: 0.9875 - val_loss: 0.0312 - val_accuracy: 0.9938 - val_auc: 0.9999 - val_precision: 0.9938 - val_recall: 0.9931
#
# Epoch 00031: val_loss did not improve from 0.02745
# Epoch 32/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0555 - accuracy: 0.9885 - auc: 0.9998 - precision: 0.9897 - recall: 0.9859 - val_loss: 0.0412 - val_accuracy: 0.9938 - val_auc: 0.9999 - val_precision: 0.9938 - val_recall: 0.9918
#
# Epoch 00032: val_loss did not improve from 0.02745
# Epoch 33/100
# 59/59 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9871 - auc: 0.9997 - precision: 0.9888 - recall: 0.9844 - val_loss: 0.0377 - val_accuracy: 0.9918 - val_auc: 0.9999 - val_precision: 0.9931 - val_recall: 0.9918
#
# Epoch 00033: val_loss did not improve from 0.02745
# Epoch 00033: early stopping
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       412
#            1       1.00      0.97      0.99       374
#            2       1.00      1.00      1.00       342
#            3       0.98      0.99      0.99       200
#            4       0.99      1.00      1.00       128
#
#     accuracy                           0.99      1456
#    macro avg       0.99      0.99      0.99      1456
# weighted avg       0.99      0.99      0.99      1456
#
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9966 - auc: 1.0000 - precision: 0.9966 - recall: 0.9966
# Memory Usage: 254.66 Mb
# Required Time: 89.78125 sec

# %%
# thr=0.95
# n_genes = math.ceil((1 - thr) * adata.var.shape[0])


# t=time.process_time()
# tracemalloc.start()
# # Run SHAP to identify marker genes
# selected_genes, selected_genes_dict = smash.run_shap(adata, group_by='louvain', pct=0.5, restrict_top=("global", n_genes))

# current, peak = tracemalloc.get_traced_memory()
# print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
# print(f'Required Time: {time.process_time() - t} sec')
# tracemalloc.stop()

# %% [markdown]
# # Cluster Reconstructed Dataset (SMaSH)

# %%
print(f'\nTotal Marker genes ({len(selected_genes)}): ')
expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
# expr_data.to_csv('expr_processed.csv')
# expression data with only marker genes
expr_data = expr_data.loc[selected_genes]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

if "X_pca" not in rcdata.obsm and "neighbors" not in rcdata.uns:
  sc.pp.pca(rcdata, n_comps=50)
  sc.pp.neighbors(rcdata, n_pcs=50)
smash_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.07)
# Out:
# Total Marker genes (1000):
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7276 × 1000
#     obs: 'cluster'
#
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.4331
# Normalized Mutual Information (NMI): 0.5516
# Silhouette Score: 0.4676

# %% [markdown]
# # Cosg Marker Genes

# %%
import cosg as cosg
import importlib
importlib.reload(cosg)
# Out:
# <module 'cosg' from 'D:\\FYDP\\Implementation\\Notebooks\\python3.8\\lib\\site-packages\\cosg\\__init__.py'>

# %%
t=time.process_time()
tracemalloc.start()

cosg.cosg(adata,
    key_added='cosg',
        mu=1,
        n_genes_user=300,
               groupby='louvain')

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# **finished identifying marker genes by COSG**
# Memory Usage: 4683.91 Mb
# Required Time: 8.765625 sec

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7276 × 42169
#     obs: 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'umap', 'cosg'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# cosg_marker_genes = np.unique(np.array(adata.uns['cosg']['names'])).tolist()
cosg_marker_genes = pd.unique(pd.DataFrame(adata.uns['cosg']['names']).values.ravel()).tolist()

# %% [markdown]
# # Cluster Reconstructed Dataset (Cosg)

# %%
cosg_expr_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
# expr_data.to_csv('expr_processed.csv')
# expression data with only high marker genes
cosg_expr_data = cosg_expr_data.loc[cosg_marker_genes]
# expr_data = expr_data.loc[marker_genes]
cosg_expr_data.shape

cgdata = sc.AnnData(X=cosg_expr_data.values.T)
cgdata.var_names = cosg_expr_data.index
cgdata.obs_names = cosg_expr_data.columns
cgdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(cgdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7276 × 1500
#     obs: 'cluster'

# %%
if "X_pca" not in cgdata.obsm and "neighbors" not in cgdata.uns:
  sc.pp.pca(cgdata, n_comps=50)
  sc.pp.neighbors(cgdata, n_pcs=50)
cosg_sil_scores = cluster_with_louvain(cgdata, epochs=1, resolution=0.078 )
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.6856
# Normalized Mutual Information (NMI): 0.6450
# Silhouette Score: 0.4552

# %% [markdown]
# # Unified Marker Genes (CellTICS + COSG+ SMaSH)

# %%
silhouette_scores = {
    'celltics': cellTICS_sil_scores,
    'cosg': cosg_sil_scores,
    'smash': smash_sil_scores
}
print('silhouette scores: ', silhouette_scores)
methods_importance = calculate_importance(silhouette_scores)
print('methods_importance: ', methods_importance)
# Out:
# silhouette scores:  {'celltics': [0.46759564], 'cosg': [0.45524696], 'smash': [0.46759564]}
# methods_importance:  {'celltics': 0.33629371455994395, 'cosg': 0.32741257088011205, 'smash': 0.33629371455994395}

# %%
# getting genes with highest weights
# methods_importance = {
#     'celltics': 0.349,
#     'cosg': 0.382,
#     'smash': 0.267
# }
UMG = pd.unique(score_marker_genes(high_markers,cosg_marker_genes,selected_genes, methods_importance, p=0.95))
# Out:
# total genes: 8639
# selected genes: 8207

# %%
len(UMG)
# Out:
# 8207

# %%
exp_data = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)
exp_data = exp_data.loc[UMG]

ccdata = sc.AnnData(X=exp_data.values.T)
ccdata.var_names = exp_data.index
ccdata.obs_names = exp_data.columns
ccdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(ccdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7276 × 8207
#     obs: 'cluster'

# %%
if "X_pca" not in ccdata.obsm and "neighbors" not in ccdata.uns:
  sc.pp.pca(ccdata, n_comps=50)
  sc.pp.neighbors(ccdata, n_pcs=50)
cluster_with_louvain(ccdata, epochs=1, resolution=0.07)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.4600
# Normalized Mutual Information (NMI): 0.5714
