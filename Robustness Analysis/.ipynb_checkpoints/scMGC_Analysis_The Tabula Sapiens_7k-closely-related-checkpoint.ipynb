# %% [markdown]
# # Installation and Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import math
import pandas as pd
import scanpy as sc
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, silhouette_score
import time
import tracemalloc
from tensorflow.keras.regularizers import l2

# %%
import scvi
# Out:
# Global seed set to 0

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# scanpy==1.9.6 anndata==0.9.2 umap==0.5.7 numpy==1.19.5 scipy==1.10.1 pandas==1.4.4 scikit-learn==1.3.2 statsmodels==0.14.1 igraph==0.11.8 louvain==0.8.2 pynndescent==0.5.13

# %% [markdown]
# # Defined Methods

# %% [markdown]
# ## Data Preprocessing

# %%
def data_init_x(path):
    print("\n==========================  Data Initialization  =================================\n")
    
    adata = sc.read_h5ad(path)

    adata.obs["cluster"] = adata.obs["cell_type"]

    print("Loaded Dataset Structure (preview 10×10):")

    # SAFE preview for sparse matrix
    X_preview = adata.X[:10, :10]
    if sp.issparse(X_preview):
        X_preview = X_preview.toarray()

    print(
        pd.DataFrame(
            X_preview,
            index=adata.obs.index[:10],
            columns=adata.var.index[:10]
        )
    )

    print("\nAnnData summary:")
    print(adata)

    print("\nTotal Clusters:")
    print(np.unique(adata.obs["cluster"]))

    print("\nCluster labels (first 20):")
    print(adata.obs["cluster"].head(20).values)

    # PCA + neighbors + UMAP
    sc.pp.pca(adata, n_comps=50)
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)

    print("\nExisting Cluster (UMAP)")
    sc.pl.umap(adata, color="cluster")

    return adata

# %%
def data_init(path):
    print("\n==========================  Data Initialization  =================================\n")
    data = pd.read_csv(path, index_col=0).astype('float64')
    clusters = data.columns
    clusters = [int(x) for x in [float(x) for x in clusters]]
    adata = sc.AnnData(X=(data.values.T))
    adata.var_names = data.index
    adata.obs_names = [f"cell-{i}" for i in range(1, len(clusters) + 1)]
    adata.obs["cluster"] = clusters
    print("Loaded Dataset Structure: ")
    print((pd.DataFrame(adata.X, index=adata.obs.index, columns=adata.var.index)).iloc[:10, :10])
    print(adata)
    print(f'Total Clusters: \n{np.unique(adata.obs["cluster"])}')
    print(f'Clusters: \n{adata.obs["cluster"]}')
    sc.pp.pca(adata, n_comps=50) 
    sc.pp.neighbors(adata, n_pcs=50)
    sc.tl.umap(adata)
    print("Existing Cluster")
    sc.pl.umap(adata, color='cluster')
    return adata

# %%
def data_processing(adata):
  print("\n==========================  Data Processing  =================================\n")
  sc.pp.filter_cells(adata, min_genes=200)
  sc.pp.filter_genes(adata, min_cells=3)
  sc.pp.normalize_per_cell(adata)
  sc.pp.log1p(adata, copy=True)
  return adata

# %% [markdown]
# ## Remove Batch Effects

# %%
def remove_batch_effect(adata, batch_key='batch', n_pcs=20, method='harmony'):
    
    if batch_key not in adata.obs:
        raise KeyError(f"Batch key '{batch_key}' not found in adata.obs")
    
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    
    sc.pp.highly_variable_genes(adata, flavor='cell_ranger', n_top_genes=2000)
    adata = adata[:, adata.var['highly_variable']].copy()
    sc.pp.scale(adata, max_value=10)
    
    sc.tl.pca(adata, n_comps=n_pcs, svd_solver='arpack')
    
    if method.lower() == 'harmony':
        ho = hm.run_harmony(adata.obsm['X_pca'], adata.obs, batch_key)
        adata.obsm['X_pca_harmony'] = ho.Z_corr
        sc.pp.neighbors(adata, use_rep='X_pca_harmony')
    elif method.lower() == 'bbknn':
        sce.pp.bbknn(adata, batch_key=batch_key, n_pcs=n_pcs)
    else:
        raise ValueError("Method must be 'harmony' or 'bbknn'.")
    
    sc.tl.umap(adata)

# %% [markdown]
# ## Denoising

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import scanpy as sc
import numpy as np

def Denoise(adata):
    
    # Step 1: Load and preprocess data
    X = adata.X  # Assuming adata.X is in sparse format
    X = X.toarray() if hasattr(X, "toarray") else X  # Convert to dense if sparse
    
    # Normalize and scale data
    X = sc.pp.log1p(X, copy=True)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    # Step 2: Add sparse noise to mimic biological dropout
    def add_sparse_noise(data, dropout_rate=0.1):
        """
        Adds sparse dropout noise to mimic missing data in scRNA-seq.
        """
        noisy_data = data.copy()
        mask = np.random.binomial(1, dropout_rate, size=data.shape)  # Create dropout mask
        noisy_data[mask == 1] = 0  # Set selected values to zero
        return noisy_data
    
    X_noisy = add_sparse_noise(X)
    
    # Step 3: Define sparse-aware denoising autoencoder
    input_dim = X.shape[1]
    
    # Encoder
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(512, activation='relu')(input_layer)
    encoded = BatchNormalization()(encoded)
    encoded = Dropout(0.2)(encoded)
    latent_space = Dense(128, activation='relu')(encoded)
    
    # Decoder
    decoded = Dense(512, activation='relu')(latent_space)
    decoded = BatchNormalization()(decoded)
    decoded = Dropout(0.2)(decoded)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    # Autoencoder model
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    
    # Custom sparse-aware loss
    def sparse_mse(y_true, y_pred):
        """
        Custom loss to preserve zeros and penalize large changes to nonzero values.
        """
        mask = tf.cast(tf.equal(y_true, 0.0), tf.float32)  # Mask for zeros in original data
        nonzero_loss = tf.reduce_mean(tf.square((1 - mask) * (y_true - y_pred)))  # Penalize changes to nonzeros
        zero_loss = tf.reduce_mean(tf.square(mask * y_pred))  # Penalize predicted values where true value is zero
        return nonzero_loss + 0.1 * zero_loss  # Combine losses with weight for zero preservation
    
    # Compile the model
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                        loss=sparse_mse,
                        metrics=['mae'])
    
    # Step 4: Train the model
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
    X_noisy_train, X_noisy_val = train_test_split(X_noisy, test_size=0.2, random_state=42)
    
    history = autoencoder.fit(
        X_noisy_train, X_train,
        validation_data=(X_noisy_val, X_val),
        epochs=200,
        batch_size=256,
        shuffle=True,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
        ]
    )
    
    # Step 5: Denoise the data
    X_denoised = autoencoder.predict(X_noisy)
    
    # Save the denoised output
    adata.X = scaler.inverse_transform(X_denoised)  # Inverse scaling
    return adata

# %% [markdown]
# ## Clustering

# %%
def cluster_with_louvain(adata, epochs, resolution=2.5):
  print("\n========================== Clustering With Louvain =================================\n")
  # if "X_pca" not in adata.obsm and "neighbors" not in adata.uns:
  sc.pp.pca(adata)
  sc.pp.neighbors(adata)
  sil_scores = []

  for i in range(0, epochs):
    sc.tl.louvain(adata, resolution)

    print(f"\nClustering epoch {i+1} ------------------")
    ari = adjusted_rand_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Adjusted Rand Index (ARI): {ari:.4f}")

    nmi = normalized_mutual_info_score(adata.obs['cluster'], adata.obs['louvain'])
    print(f"Normalized Mutual Information (NMI): {nmi:.4f}")

    X = adata.obsm["X_pca"]
    sil_score = silhouette_score(X, adata.obs['louvain'])
    sil_scores.append(sil_score)
    print(f"Silhouette Score: {sil_score:.4f}\n")

      
  sc.tl.umap(adata)
  sc.pl.umap(adata, color='louvain')
  return sil_scores

# %% [markdown]
# ## Identify Marker Gene

# %% [markdown]
# ### CellTICS

# %%
# Define fphi - High markers
def fphi(x):
    normalized = (x + 1).div(x.max(axis=1) + 1, axis=0)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)
    zp = normalized.mul(zt, axis=0)
    return zp

# Define frho - Low markers
def frho(x):
    normalized = (1 / (x + 1)).mul(x.min(axis=1) + 1, axis=0)
    zt = (1 - normalized).sum(axis=1) / (x.shape[1] - 1)
    zp = normalized.mul(zt, axis=0)
    return zp

def CellTICS_marker_genes(adata, thr1=0.95, thr2=0.9):
    print("\n====================== Identify Marker Gene With CellTICS ============================\n")
    print("Expression Values of Genes: \n")
    
    X_dense = adata.X
    if hasattr(X_dense, 'toarray'):
        X_dense = X_dense.toarray()
    
    expr_data = pd.DataFrame(
        X_dense.T,
        index=adata.var_names,
        columns=adata.obs_names
    )
    
    louvain_labels = pd.Series(adata.obs['louvain'].values, index=adata.obs_names)
    print(expr_data.iloc[:10, :10])
    print(adata)

    print("\nAverage the cell expr data according to the clusters:\n")
    avg_expr_data = expr_data.T.groupby(louvain_labels).mean().T
    print(avg_expr_data.iloc[:10, :])

    phi = fphi(avg_expr_data)
    rho = frho(avg_expr_data)

    gnm = phi.index.values 
    ctpnm = phi.columns.values

    phi = np.array(phi)
    rho = np.array(rho)

    nummkg1 = math.ceil((1 - thr1) * phi.shape[0]) 
    nummkg2 = math.ceil((1 - thr2) * phi.shape[0]) 

    alpha = [] 
    beta = []
    for i in range(0, phi.shape[1]):
        alpha.append(np.quantile(phi[:, i], thr1))
        beta.append(np.quantile(rho[:, i], thr2))

    mkh = [] 
    mkl = [] 
    for i in range(0, phi.shape[1]):
        high_markers = gnm[phi[:, i] >= alpha[i]][0:nummkg1]
        low_markers = gnm[rho[:, i] >= beta[i]][0:nummkg2]
        mkh = np.concatenate([mkh, high_markers], axis=0) if len(mkh) > 0 else high_markers
        mkl = np.concatenate([mkl, low_markers], axis=0) if len(mkl) > 0 else low_markers

    mkh = mkh.reshape(nummkg1, phi.shape[1])
    mkl = mkl.reshape(nummkg2, rho.shape[1])
    mkh = pd.DataFrame(mkh, columns=ctpnm)
    mkl = pd.DataFrame(mkl, columns=ctpnm)

    print("\nHigh Marker Genes for each cluster/type: \n")
    print(mkh.iloc[:10, :])

    print("\nLow Marker Genes for each cluster/type: \n")
    print(mkl.iloc[:10, :])

    return mkh, mkl

# %%
# getting list of all high and low marker genes
def get_unique_marker_genes(high_markers):
  unique_high_markers = high_markers
  unique_high_markers = pd.unique(unique_high_markers.values.ravel()).tolist()
  print(f"\nTotal Unique High Marker Gene for all together {len(unique_high_markers)}: ")
  return unique_high_markers

# %% [markdown]
# ## Calculate Importance

# %%
def calculate_importance(silhouette_scores):
    avg_scores = {k: sum(v) / len(v) for k, v in silhouette_scores.items()}
    
    total = sum(avg_scores.values())
    return {k: v / total for k, v in avg_scores.items()}

# %% [markdown]
# ## Unified Marker Genes (Weight Based)

# %%
from collections import defaultdict

def score_marker_genes(celltics_genes, smash_genes, cosg_genes, importance, p=1.0):
    
    gene_weights = defaultdict(float)
    
    for gene in celltics_genes:
        gene_weights[gene] += importance['celltics']
        
    for gene in smash_genes:
        gene_weights[gene] += importance['smash']
        
    for gene in cosg_genes:
        gene_weights[gene] += importance['cosg']
    
    selected_genes = sorted(gene_weights.items(), key=lambda x: x[1], reverse=True) # selecting genes with highest weight

    print(f'total genes: {len(selected_genes)}')
    
    top_n = int(len(selected_genes) * p)

    print(f'selected genes: {top_n}')
    
    return [gene for gene, weight in selected_genes[:top_n]]

# %% [markdown]
# # Implementations____________

# %%
import scipy.sparse as sp

# %%
# dataset_path = "88930108-9c98-43a7-826d-ce454dd0c930.h5ad"


# adata = data_processing(adata)

# adata = Denoise(adata)

# adata = sc.read_h5ad("new-7k-processed.h5ad")
adata = data_init_x("new-7k-processed.h5ad")
adata = data_processing(adata)
# Out:
# ==========================  Data Initialization  =================================
#
# Loaded Dataset Structure (preview 10×10):
#                                                    ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  ENSG00000001084  ENSG00000001167
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96D3         0.284173         0.002804         0.183652         0.039676         0.076055         0.000927         0.036624         0.053667         0.098435         0.153108
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A3         0.283847         0.002791         0.183491         0.039119         0.073234         0.000926         0.036584         0.053671         0.098443         0.150288
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96A2         0.283489         0.002761         0.183466         0.042328         0.095903         0.000926         0.039389         0.053671         0.098445         0.148382
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96H2         0.288920         0.002865         0.183716         0.038702         0.068615         0.000926         0.038330         0.053671         0.098444         0.150513
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96E3         0.284251         0.002869         0.183627         0.042195         0.082430         0.000927         0.037213         0.053666         0.098424         0.155925
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B3         0.283749         0.002766         0.183481         0.038666         0.073394         0.000926         0.039246         0.053671         0.098445         0.150504
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C2         0.284198         0.002786         0.183598         0.039352         0.074217         0.000927         0.038704         0.053670         0.098444         0.152047
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96F3         0.283676         0.002761         0.183480         0.039208         0.078183         0.000926         0.039009         0.053671         0.098445         0.147565
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96C3         0.283795         0.002774         0.183517         0.039311         0.078401         0.000926         0.038697         0.053671         0.098444         0.151337
# TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582_Oocyte_96B2         0.283494         0.002760         0.183466         0.038531         0.079323         0.000926         0.039390         0.053671         0.098445         0.146331
#
# AnnData summary:
# AnnData object with n_obs × n_vars = 7276 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'cluster_colors', 'compartment_colors', 'donor_id_colors', 'leiden', 'louvain', 'louvain_colors', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'
#
# Total Clusters:
# ['male germ cell' 'oocyte' 'spermatid' 'spermatocyte' 'spermatogonium']
#
# Cluster labels (first 20):
# ['oocyte', 'oocyte', 'oocyte', 'oocyte', 'oocyte', ..., 'spermatid', 'male germ cell', 'spermatocyte', 'spermatid', 'spermatocyte']
# Length: 20
# Categories (5, object): ['male germ cell', 'spermatocyte', 'spermatid', 'spermatogonium', 'oocyte']
# computing PCA
#     with n_comps=50
#     finished (0:00:13)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:07)
#
# Existing Cluster (UMAP)
# ==========================  Data Processing  =================================
#
# normalizing by total count per cell
#     finished (0:00:02): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
closely_related = [
    'spermatogonium',
    'spermatocyte',
    'spermatid'
]

adata = adata[
    adata.obs['cell_type'].isin(closely_related)
].copy()

print("\nClosely-related AnnData")
print(adata)
print(adata.obs['cell_type'].value_counts())
# Out:
# Closely-related AnnData
# AnnData object with n_obs × n_vars = 7143 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'cluster_colors', 'compartment_colors', 'donor_id_colors', 'leiden', 'louvain', 'louvain_colors', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'
# spermatid         4009
# spermatocyte      3070
# spermatogonium      64
# Name: cell_type, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7143 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'cluster_colors', 'compartment_colors', 'donor_id_colors', 'leiden', 'louvain', 'louvain_colors', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # CellTICS Marker Genes

# %%
# adata.write_h5ad("new-7k-processed.h5ad")

# %%
adata.obs["cluster"]
# Out:
# TSP25_Testis_NA_10X_1_2_AAACCCAAGATTGGGC       spermatid
# TSP25_Testis_NA_10X_1_2_AAACCCACACTTGAAC    spermatocyte
# TSP25_Testis_NA_10X_1_2_AAACCCAGTCCAGCAC       spermatid
# TSP25_Testis_NA_10X_1_2_AAACCCAGTGACACAG       spermatid
# TSP25_Testis_NA_10X_1_2_AAACCCATCCCGAGTG       spermatid
#                                                 ...
# TSP25_Testis_NA_10X_1_1_TTTGGTTGTCGGCACT    spermatocyte
# TSP25_Testis_NA_10X_1_1_TTTGGTTGTTCCTACC       spermatid
# TSP25_Testis_NA_10X_1_1_TTTGTTGCAATTCTCT       spermatid
# TSP25_Testis_NA_10X_1_1_TTTGTTGCATGACTAC    spermatocyte
# TSP25_Testis_NA_10X_1_1_TTTGTTGTCCGTCCTA    spermatocyte
# Name: cluster, Length: 7143, dtype: category
# Categories (3, object): ['spermatocyte', 'spermatid', 'spermatogonium']

# %%
cluster_with_louvain(adata, epochs=1, resolution=0.03)
t=time.process_time()
tracemalloc.start()

high_markers, low_markers = CellTICS_marker_genes(adata, thr1=0.80, thr2= 0.80)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()


high_markers = get_unique_marker_genes(high_markers)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:12)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.6337
# Normalized Mutual Information (NMI): 0.6120
# Silhouette Score: 0.4451
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:07)
# ====================== Identify Marker Gene With CellTICS ============================
#
# Expression Values of Genes:
#
#                  TSP25_Testis_NA_10X_1_2_AAACCCAAGATTGGGC  TSP25_Testis_NA_10X_1_2_AAACCCACACTTGAAC  TSP25_Testis_NA_10X_1_2_AAACCCAGTCCAGCAC  TSP25_Testis_NA_10X_1_2_AAACCCAGTGACACAG  TSP25_Testis_NA_10X_1_2_AAACCCATCCCGAGTG  TSP25_Testis_NA_10X_1_2_AAACGAAGTTAAGGAT  TSP25_Testis_NA_10X_1_2_AAACGAAGTTATGTGC  TSP25_Testis_NA_10X_1_2_AAACGCTAGCGCCATC  TSP25_Testis_NA_10X_1_2_AAACGCTGTCAGGTGA  TSP25_Testis_NA_10X_1_2_AAACGCTTCATTATCC
# ENSG00000000003                                  0.425823                                  0.252414                                  0.570448                                  0.454882                                  0.331650                                  0.256711                                  0.553977                                  0.255960                                  0.245843                                  0.554893
# ENSG00000000005                                  0.003007                                  0.002726                                  0.004739                                  0.002983                                  0.003144                                  0.002989                                  0.003035                                  0.002559                                  0.002465                                  0.003237
# ENSG00000000419                                  0.198039                                  0.163711                                  0.328258                                  0.211745                                  0.314061                                  0.166594                                  0.208934                                  0.172269                                  0.166971                                  0.244241
# ENSG00000000457                                  0.041151                                  0.039551                                  0.039883                                  0.039931                                  0.036679                                  0.064365                                  0.041643                                  0.059434                                  0.067129                                  0.039557
# ENSG00000000460                                  0.071850                                  0.072228                                  0.069936                                  0.069848                                  0.064397                                  0.109926                                  0.072772                                  0.215892                                  0.191935                                  0.069183
# ENSG00000000938                                  0.001062                                  0.001136                                  0.001127                                  0.001235                                  0.001591                                  0.003230                                  0.001138                                  0.000922                                  0.000844                                  0.001531
# ENSG00000000971                                  0.003080                                  0.009348                                  0.002711                                  0.002905                                  0.002533                                  0.006565                                  0.002840                                  0.009084                                  0.002884                                  0.002721
# ENSG00000001036                                  0.005944                                  0.004891                                  0.005355                                  0.005506                                  0.005055                                  0.009542                                  0.005664                                  0.010578                                  0.021945                                  0.005335
# ENSG00000001084                                  0.014125                                  0.011575                                  0.013826                                  0.013619                                  0.013548                                  0.011928                                  0.016018                                  0.027368                                  0.017133                                  0.015142
# ENSG00000001167                                  0.157159                                  0.168935                                  0.157535                                  0.153928                                  0.156644                                  0.201890                                  0.158836                                  0.131617                                  0.323616                                  0.153947
# AnnData object with n_obs × n_vars = 7143 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'cluster_colors', 'compartment_colors', 'donor_id_colors', 'leiden', 'louvain', 'louvain_colors', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'
#
# Average the cell expr data according to the clusters:
#
#                         0         1         2
# ENSG00000000003  0.490479  0.252367  0.311153
# ENSG00000000005  0.003166  0.002756  0.008325
# ENSG00000000419  0.224280  0.167651  0.283182
# ENSG00000000457  0.041223  0.085798  0.037718
# ENSG00000000460  0.072116  0.151039  0.065772
# ENSG00000000938  0.001125  0.002429  0.001223
# ENSG00000000971  0.003034  0.005056  0.002607
# ENSG00000001036  0.005653  0.009308  0.005174
# ENSG00000001084  0.014655  0.019733  0.014966
# ENSG00000001167  0.158840  0.197939  0.159349
#
# High Marker Genes for each cluster/type:
#
#                  0                1                2
# 0  ENSG00000000003  ENSG00000000419  ENSG00000000457
# 1  ENSG00000000460  ENSG00000001460  ENSG00000001626
# 2  ENSG00000001629  ENSG00000001630  ENSG00000001631
# 3  ENSG00000002330  ENSG00000002549  ENSG00000002746
# 4  ENSG00000002834  ENSG00000003056  ENSG00000003147
# 5  ENSG00000003402  ENSG00000003509  ENSG00000004455
# 6  ENSG00000004478  ENSG00000004487  ENSG00000004534
# 7  ENSG00000004776  ENSG00000004779  ENSG00000004809
# 8  ENSG00000004838  ENSG00000004866  ENSG00000004897
# 9  ENSG00000005007  ENSG00000005100  ENSG00000005175
#
# Low Marker Genes for each cluster/type:
#
#                  0                1                2
# 0  ENSG00000000003  ENSG00000000419  ENSG00000000460
# 1  ENSG00000001460  ENSG00000001626  ENSG00000001629
# 2  ENSG00000001630  ENSG00000002330  ENSG00000002549
# 3  ENSG00000002746  ENSG00000002834  ENSG00000003056
# 4  ENSG00000003147  ENSG00000003402  ENSG00000003509
# 5  ENSG00000004455  ENSG00000004478  ENSG00000004487
# 6  ENSG00000004534  ENSG00000004776  ENSG00000004779
# 7  ENSG00000004809  ENSG00000004838  ENSG00000004866
# 8  ENSG00000004897  ENSG00000005007  ENSG00000005020
# 9  ENSG00000005100  ENSG00000005175  ENSG00000005187
# Memory Usage: 2302.12 Mb
# Required Time: 1.1875 sec
#
# Total Unique High Marker Gene for all together 8602:

# %% [markdown]
# # Cluster Reconstructed Dataset (CellTICS)

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)
expr_data = expr_data.loc[high_markers]
expr_data.shape

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7143 × 8602
#     obs: 'cluster'

# %%
# rc_pd = pd.DataFrame(rcdata.X.T, index=rcdata.var_names, columns=rcdata.obs_names)
# rc_pd.to_csv('rc_processed.csv')

# %%
cellTICS_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.03)
# Out:
# ========================== Clustering With Louvain =================================
#
# computing PCA
#     with n_comps=50
#     finished (0:00:02)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:01)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 3 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.6340
# Normalized Mutual Information (NMI): 0.6121
# Silhouette Score: 0.4676
#
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:07)

# %% [markdown]
# # Smash Marker Genes

# %%
# adata.write_h5ad("new_processed.h5ad")

# %%
# adata = sc.read_h5ad("new_processed.h5ad")

# %%
import os
import smashpy

smash = smashpy.smashpy()

X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

if np.any(np.isnan(X_dense)):
    if hasattr(adata.X, 'toarray'):
        adata.X = np.nan_to_num(X_dense)
    else:
        adata.X = np.nan_to_num(adata.X)

if not os.path.exists('Figures'):
    os.makedirs('Figures')

# smash.DNN(adata, group_by='louvain')
# Out:
#  * Initialising ...
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\smashpy.py:72: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
# import numpy as np
# import scipy.sparse as sp

# clusters = adata.obs["louvain"].unique()

# X_bulk = []
# for c in clusters:
#     idx = adata.obs["louvain"] == c
#     Xc = adata.X[idx]
#     X_bulk.append(Xc.mean(axis=0))

# X_bulk = np.vstack([x.A if sp.issparse(x) else x for x in X_bulk])

# adata_bulk = sc.AnnData(
#     X=X_bulk,
#     var=adata.var.copy(),
#     obs=pd.DataFrame({"cluster": clusters})
# )

# print(adata_bulk)

# %%
# 1. Select HVGs FIRST
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    flavor="seurat"
)

adata_hvg = adata[:, adata.var.highly_variable].copy()

# 2. Convert to dense and replace X
if hasattr(adata_hvg.X, 'toarray'):
    adata_hvg.X = adata_hvg.X.toarray()

# 3. Train Smash DNN on HVGs
smash.DNN(adata_hvg, group_by='louvain')

t = time.process_time()
tracemalloc.start()

# 4. Run SHAP on the SAME adata_hvg
selected_genes, selected_genes_dict = smash.run_shap(
    adata_hvg,
    group_by='louvain',
    pct=0.2,
    restrict_top=("global", 1000)
)

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb')
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                64032
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# activation (Activation)      (None, 32)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 64,803
# Trainable params: 64,707
# Non-trainable params: 96
# _________________________________________________________________
# None
# WARNING:tensorflow:From D:\FYDP\Implementation\Notebooks\python3.8\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 58/58 [==============================] - 2s 11ms/step - loss: 0.6577 - accuracy: 0.7987 - auc: 0.9336 - precision: 0.9544 - recall: 0.5310 - val_loss: 0.7449 - val_accuracy: 0.9923 - val_auc: 0.9994 - val_precision: 1.0000 - val_recall: 0.2155
#
# Epoch 00001: val_loss improved from inf to 0.74492, saving model to weights\best_model_louvain.h5
# Epoch 2/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.4927 - accuracy: 0.9454 - auc: 0.9920 - precision: 0.9839 - recall: 0.8105 - val_loss: 0.5117 - val_accuracy: 0.9916 - val_auc: 0.9998 - val_precision: 0.9993 - val_recall: 0.9608
#
# Epoch 00002: val_loss improved from 0.74492 to 0.51171, saving model to weights\best_model_louvain.h5
# Epoch 3/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.3960 - accuracy: 0.9720 - auc: 0.9969 - precision: 0.9905 - recall: 0.9097 - val_loss: 0.3689 - val_accuracy: 0.9930 - val_auc: 0.9999 - val_precision: 0.9979 - val_recall: 0.9832
#
# Epoch 00003: val_loss improved from 0.51171 to 0.36893, saving model to weights\best_model_louvain.h5
# Epoch 4/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.3199 - accuracy: 0.9799 - auc: 0.9983 - precision: 0.9914 - recall: 0.9440 - val_loss: 0.2750 - val_accuracy: 0.9944 - val_auc: 0.9999 - val_precision: 0.9979 - val_recall: 0.9902
#
# Epoch 00004: val_loss improved from 0.36893 to 0.27503, saving model to weights\best_model_louvain.h5
# Epoch 5/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.2617 - accuracy: 0.9842 - auc: 0.9990 - precision: 0.9915 - recall: 0.9643 - val_loss: 0.1967 - val_accuracy: 0.9951 - val_auc: 1.0000 - val_precision: 0.9972 - val_recall: 0.9930
#
# Epoch 00005: val_loss improved from 0.27503 to 0.19668, saving model to weights\best_model_louvain.h5
# Epoch 6/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9874 - auc: 0.9991 - precision: 0.9918 - recall: 0.9767 - val_loss: 0.1616 - val_accuracy: 0.9972 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9951
#
# Epoch 00006: val_loss improved from 0.19668 to 0.16163, saving model to weights\best_model_louvain.h5
# Epoch 7/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1817 - accuracy: 0.9890 - auc: 0.9995 - precision: 0.9929 - recall: 0.9814 - val_loss: 0.1149 - val_accuracy: 0.9972 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9958
#
# Epoch 00007: val_loss improved from 0.16163 to 0.11486, saving model to weights\best_model_louvain.h5
# Epoch 8/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1600 - accuracy: 0.9888 - auc: 0.9994 - precision: 0.9928 - recall: 0.9828 - val_loss: 0.1045 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00008: val_loss improved from 0.11486 to 0.10452, saving model to weights\best_model_louvain.h5
# Epoch 9/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9904 - auc: 0.9996 - precision: 0.9931 - recall: 0.9872 - val_loss: 0.0865 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9972
#
# Epoch 00009: val_loss improved from 0.10452 to 0.08654, saving model to weights\best_model_louvain.h5
# Epoch 10/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9916 - auc: 0.9995 - precision: 0.9937 - recall: 0.9888 - val_loss: 0.0735 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9972
#
# Epoch 00010: val_loss improved from 0.08654 to 0.07347, saving model to weights\best_model_louvain.h5
# Epoch 11/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.1038 - accuracy: 0.9921 - auc: 0.9997 - precision: 0.9942 - recall: 0.9888 - val_loss: 0.0623 - val_accuracy: 0.9958 - val_auc: 0.9999 - val_precision: 0.9965 - val_recall: 0.9951
#
# Epoch 00011: val_loss improved from 0.07347 to 0.06230, saving model to weights\best_model_louvain.h5
# Epoch 12/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9911 - auc: 0.9995 - precision: 0.9926 - recall: 0.9891 - val_loss: 0.0483 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9979 - val_recall: 0.9972
#
# Epoch 00012: val_loss improved from 0.06230 to 0.04826, saving model to weights\best_model_louvain.h5
# Epoch 13/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0796 - accuracy: 0.9933 - auc: 0.9998 - precision: 0.9947 - recall: 0.9919 - val_loss: 0.0464 - val_accuracy: 0.9979 - val_auc: 0.9997 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00013: val_loss improved from 0.04826 to 0.04642, saving model to weights\best_model_louvain.h5
# Epoch 14/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9928 - auc: 0.9999 - precision: 0.9939 - recall: 0.9911 - val_loss: 0.0352 - val_accuracy: 0.9965 - val_auc: 1.0000 - val_precision: 0.9972 - val_recall: 0.9965
#
# Epoch 00014: val_loss improved from 0.04642 to 0.03517, saving model to weights\best_model_louvain.h5
# Epoch 15/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9946 - auc: 0.9998 - precision: 0.9951 - recall: 0.9935 - val_loss: 0.0340 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00015: val_loss improved from 0.03517 to 0.03405, saving model to weights\best_model_louvain.h5
# Epoch 16/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9960 - auc: 0.9998 - precision: 0.9963 - recall: 0.9944 - val_loss: 0.0368 - val_accuracy: 0.9986 - val_auc: 0.9999 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00016: val_loss did not improve from 0.03405
# Epoch 17/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0539 - accuracy: 0.9963 - auc: 0.9998 - precision: 0.9967 - recall: 0.9956 - val_loss: 0.0275 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00017: val_loss improved from 0.03405 to 0.02746, saving model to weights\best_model_louvain.h5
# Epoch 18/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9961 - auc: 1.0000 - precision: 0.9967 - recall: 0.9956 - val_loss: 0.0293 - val_accuracy: 0.9965 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9958
#
# Epoch 00018: val_loss did not improve from 0.02746
# Epoch 19/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 0.9960 - auc: 1.0000 - precision: 0.9963 - recall: 0.9954 - val_loss: 0.0304 - val_accuracy: 0.9972 - val_auc: 0.9999 - val_precision: 0.9972 - val_recall: 0.9965
#
# Epoch 00019: val_loss did not improve from 0.02746
# Epoch 20/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9942 - auc: 0.9999 - precision: 0.9947 - recall: 0.9937 - val_loss: 0.0236 - val_accuracy: 0.9958 - val_auc: 1.0000 - val_precision: 0.9958 - val_recall: 0.9958
#
# Epoch 00020: val_loss improved from 0.02746 to 0.02356, saving model to weights\best_model_louvain.h5
# Epoch 21/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9953 - auc: 0.9999 - precision: 0.9960 - recall: 0.9946 - val_loss: 0.0362 - val_accuracy: 0.9979 - val_auc: 0.9994 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00021: val_loss did not improve from 0.02356
# Epoch 22/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9935 - auc: 0.9998 - precision: 0.9939 - recall: 0.9926 - val_loss: 0.0168 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00022: val_loss improved from 0.02356 to 0.01676, saving model to weights\best_model_louvain.h5
# Epoch 23/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9949 - auc: 0.9999 - precision: 0.9953 - recall: 0.9949 - val_loss: 0.0184 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00023: val_loss did not improve from 0.01676
# Epoch 24/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0359 - accuracy: 0.9942 - auc: 0.9999 - precision: 0.9944 - recall: 0.9935 - val_loss: 0.0167 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00024: val_loss improved from 0.01676 to 0.01673, saving model to weights\best_model_louvain.h5
# Epoch 25/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9963 - auc: 1.0000 - precision: 0.9965 - recall: 0.9961 - val_loss: 0.0180 - val_accuracy: 0.9986 - val_auc: 0.9999 - val_precision: 0.9993 - val_recall: 0.9986
#
# Epoch 00025: val_loss did not improve from 0.01673
# Epoch 26/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9960 - auc: 0.9999 - precision: 0.9963 - recall: 0.9956 - val_loss: 0.0219 - val_accuracy: 0.9965 - val_auc: 0.9996 - val_precision: 0.9965 - val_recall: 0.9965
#
# Epoch 00026: val_loss did not improve from 0.01673
# Epoch 27/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9979 - recall: 0.9975 - val_loss: 0.0222 - val_accuracy: 0.9958 - val_auc: 0.9995 - val_precision: 0.9958 - val_recall: 0.9958
#
# Epoch 00027: val_loss did not improve from 0.01673
# Epoch 28/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9981 - auc: 1.0000 - precision: 0.9982 - recall: 0.9977 - val_loss: 0.0168 - val_accuracy: 0.9979 - val_auc: 0.9997 - val_precision: 0.9986 - val_recall: 0.9979
#
# Epoch 00028: val_loss did not improve from 0.01673
# Epoch 29/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9967 - auc: 0.9999 - precision: 0.9968 - recall: 0.9963 - val_loss: 0.0155 - val_accuracy: 0.9972 - val_auc: 0.9995 - val_precision: 0.9972 - val_recall: 0.9972
#
# Epoch 00029: val_loss improved from 0.01673 to 0.01546, saving model to weights\best_model_louvain.h5
# Epoch 30/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9958 - auc: 0.9998 - precision: 0.9960 - recall: 0.9956 - val_loss: 0.0133 - val_accuracy: 0.9986 - val_auc: 0.9998 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00030: val_loss improved from 0.01546 to 0.01326, saving model to weights\best_model_louvain.h5
# Epoch 31/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9974 - auc: 0.9999 - precision: 0.9974 - recall: 0.9972 - val_loss: 0.0154 - val_accuracy: 0.9986 - val_auc: 0.9993 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00031: val_loss did not improve from 0.01326
# Epoch 32/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9963 - auc: 1.0000 - precision: 0.9967 - recall: 0.9961 - val_loss: 0.0155 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00032: val_loss did not improve from 0.01326
# Epoch 33/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9977 - auc: 1.0000 - precision: 0.9981 - recall: 0.9972 - val_loss: 0.0124 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00033: val_loss improved from 0.01326 to 0.01240, saving model to weights\best_model_louvain.h5
# Epoch 34/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9965 - auc: 1.0000 - precision: 0.9967 - recall: 0.9961 - val_loss: 0.0106 - val_accuracy: 0.9979 - val_auc: 0.9996 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00034: val_loss improved from 0.01240 to 0.01061, saving model to weights\best_model_louvain.h5
# Epoch 35/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9965 - auc: 0.9998 - precision: 0.9968 - recall: 0.9960 - val_loss: 0.0113 - val_accuracy: 0.9979 - val_auc: 0.9996 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00035: val_loss did not improve from 0.01061
# Epoch 36/100
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.9974 - auc: 0.9999 - precision: 0.9974 - recall: 0.9972 - val_loss: 0.0106 - val_accuracy: 0.9979 - val_auc: 0.9996 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00036: val_loss improved from 0.01061 to 0.01056, saving model to weights\best_model_louvain.h5
# Epoch 37/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9979 - auc: 0.9999 - precision: 0.9979 - recall: 0.9975 - val_loss: 0.0099 - val_accuracy: 0.9986 - val_auc: 0.9994 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00037: val_loss improved from 0.01056 to 0.00985, saving model to weights\best_model_louvain.h5
# Epoch 38/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9974 - auc: 1.0000 - precision: 0.9975 - recall: 0.9974 - val_loss: 0.0105 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00038: val_loss did not improve from 0.00985
# Epoch 39/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9982 - auc: 1.0000 - precision: 0.9982 - recall: 0.9982 - val_loss: 0.0084 - val_accuracy: 0.9986 - val_auc: 0.9996 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00039: val_loss improved from 0.00985 to 0.00837, saving model to weights\best_model_louvain.h5
# Epoch 40/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9975 - auc: 1.0000 - precision: 0.9977 - recall: 0.9975 - val_loss: 0.0086 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00040: val_loss did not improve from 0.00837
# Epoch 41/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9967 - auc: 0.9999 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0091 - val_accuracy: 0.9979 - val_auc: 1.0000 - val_precision: 0.9979 - val_recall: 0.9979
#
# Epoch 00041: val_loss did not improve from 0.00837
# Epoch 42/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9984 - auc: 1.0000 - precision: 0.9988 - recall: 0.9981 - val_loss: 0.0276 - val_accuracy: 0.9923 - val_auc: 0.9993 - val_precision: 0.9923 - val_recall: 0.9923
#
# Epoch 00042: val_loss did not improve from 0.00837
# Epoch 43/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9951 - auc: 0.9997 - precision: 0.9951 - recall: 0.9949 - val_loss: 0.0104 - val_accuracy: 0.9972 - val_auc: 0.9995 - val_precision: 0.9972 - val_recall: 0.9972
#
# Epoch 00043: val_loss did not improve from 0.00837
# Epoch 44/100
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9972 - auc: 1.0000 - precision: 0.9975 - recall: 0.9972 - val_loss: 0.0087 - val_accuracy: 0.9986 - val_auc: 1.0000 - val_precision: 0.9986 - val_recall: 0.9986
#
# Epoch 00044: val_loss did not improve from 0.00837
# Epoch 00044: early stopping
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       686
#            1       1.00      1.00      1.00       444
#            2       1.00      1.00      1.00       299
#
#     accuracy                           1.00      1429
#    macro avg       1.00      1.00      1.00      1429
# weighted avg       1.00      1.00      1.00      1429
#
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9986 - auc: 0.9996 - precision: 0.9986 - recall: 0.9986
# Memory Usage: 240.53 Mb
# Required Time: 33.453125 sec

# %%
# thr=0.95
# n_genes = math.ceil((1 - thr) * adata.var.shape[0])


# t=time.process_time()
# tracemalloc.start()
# # Run SHAP to identify marker genes
# selected_genes, selected_genes_dict = smash.run_shap(adata, group_by='louvain', pct=0.5, restrict_top=("global", n_genes))

# current, peak = tracemalloc.get_traced_memory()
# print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
# print(f'Required Time: {time.process_time() - t} sec')
# tracemalloc.stop()

# %% [markdown]
# # Cluster Reconstructed Dataset (SMaSH)

# %%
print(f'\nTotal Marker genes ({len(selected_genes)}): ')

X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

# expression data with only marker genes
expr_data = expr_data.loc[selected_genes]
print(expr_data.shape)

rcdata = sc.AnnData(X=expr_data.values.T)
rcdata.var_names = expr_data.index
rcdata.obs_names = expr_data.columns
rcdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(rcdata)

rc_pd = pd.DataFrame(
    rcdata.X.T,
    index=rcdata.var_names,
    columns=rcdata.obs_names
)

if "X_pca" not in rcdata.obsm and "neighbors" not in rcdata.uns:
    sc.pp.pca(rcdata, n_comps=min(50, rcdata.shape[0], rcdata.shape[1]))
    sc.pp.neighbors(rcdata, n_pcs=min(50, rcdata.shape[0], rcdata.shape[1]))

smash_sil_scores = cluster_with_louvain(rcdata, epochs=1, resolution=0.03)
# Out:
# Total Marker genes (1000):
# (1000, 7143)
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7143 × 1000
#     obs: 'cluster'
#
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.6779
# Normalized Mutual Information (NMI): 0.6409
# Silhouette Score: 0.5082

# %% [markdown]
# # Cosg Marker Genes

# %%
import cosg as cosg
import importlib
importlib.reload(cosg)
# Out:
# <module 'cosg' from 'D:\\FYDP\\Implementation\\Notebooks\\python3.8\\lib\\site-packages\\cosg\\__init__.py'>

# %%
t=time.process_time()
tracemalloc.start()

cosg.cosg(adata,
    key_added='cosg',
        mu=1,
        n_genes_user=8000,
               groupby='louvain')

current, peak = tracemalloc.get_traced_memory()
print(f'Memory Usage: {(peak / (1024 ** 2)):.2f} Mb') #The output is given in form of (current, peak), i.e., current memory is the memory the code is currently using,uses and peak memory is the maximum space the program used while executing.
print(f'Required Time: {time.process_time() - t} sec')
tracemalloc.stop()
# Out:
# **finished identifying marker genes by COSG**
# Memory Usage: 4597.45 Mb
# Required Time: 5.65625 sec

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7143 × 42169
#     obs: 'donor_id', 'tissue_in_publication', 'anatomical_position', 'method', 'cdna_plate', 'library_plate', 'notes', 'cdna_well', 'assay_ontology_term_id', 'sample_id', 'replicate', '10X_run', 'ambient_removal', 'donor_method', 'donor_assay', 'donor_tissue', 'donor_tissue_assay', 'cell_type_ontology_term_id', 'compartment', 'broad_cell_class', 'free_annotation', 'manually_annotated', 'published_2022', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ercc', 'pct_counts_ercc', '_scvi_batch', '_scvi_labels', 'scvi_leiden_donorassay_full', 'ethnicity_original', 'scvi_leiden_res05_compartment', 'sample_number', 'suspension_type', 'tissue_type', 'disease_ontology_term_id', 'is_primary_data', 'tissue_ontology_term_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'cluster', 'n_genes', 'n_counts', 'louvain'
#     var: 'ensembl_id', 'genome', 'mt', 'ercc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', '_training_mode', 'assay_ontology_term_id_colors', 'citation', 'cluster_colors', 'compartment_colors', 'donor_id_colors', 'leiden', 'louvain', 'louvain_colors', 'method_colors', 'neighbors', 'organism', 'organism_ontology_term_id', 'pca', 'schema_reference', 'schema_version', 'sex_ontology_term_id_colors', 'tissue_in_publication_colors', 'title', 'umap', 'hvg', 'cosg'
#     obsm: 'X_compartment_uncorrected_umap', 'X_pca', 'X_scvi', 'X_umap', 'X_umap_compartment_scvi_donorassay', 'X_umap_scvi_full_donorassay', 'X_uncorrected_umap'
#     varm: 'PCs'
#     layers: 'decontXcounts', 'scale_data'
#     obsp: 'connectivities', 'distances'

# %%
# cosg_marker_genes = np.unique(np.array(adata.uns['cosg']['names'])).tolist()
cosg_marker_genes = pd.unique(pd.DataFrame(adata.uns['cosg']['names']).values.ravel()).tolist()

# %% [markdown]
# # Cluster Reconstructed Dataset (Cosg)

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

cosg_expr_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

cosg_expr_data = cosg_expr_data.loc[cosg_marker_genes]
print(cosg_expr_data.shape)

cgdata = sc.AnnData(X=cosg_expr_data.values.T)
cgdata.var_names = cosg_expr_data.index
cgdata.obs_names = cosg_expr_data.columns
cgdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(cgdata)
# Out:
# (23710, 7143)
#
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7143 × 23710
#     obs: 'cluster'

# %%
if "X_pca" not in cgdata.obsm and "neighbors" not in cgdata.uns:
  sc.pp.pca(cgdata, n_comps=50)
  sc.pp.neighbors(cgdata, n_pcs=50)
cosg_sil_scores = cluster_with_louvain(cgdata, epochs=1, resolution=0.03 )
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.6331
# Normalized Mutual Information (NMI): 0.6116
# Silhouette Score: 0.4753

# %% [markdown]
# # Unified Marker Genes (CellTICS + COSG+ SMaSH)

# %%
silhouette_scores = {
    'celltics': cellTICS_sil_scores,
    'cosg': cosg_sil_scores,
    'smash': smash_sil_scores
}
print('silhouette scores: ', silhouette_scores)
methods_importance = calculate_importance(silhouette_scores)
print('methods_importance: ', methods_importance)
# Out:
# silhouette scores:  {'celltics': [0.46762824], 'cosg': [0.4753208], 'smash': [0.50816494]}
# methods_importance:  {'celltics': 0.3222546612788464, 'cosg': 0.32755579255885625, 'smash': 0.35018954616229736}

# %%
# getting genes with highest weights
# methods_importance = {
#     'celltics': 0.349,
#     'cosg': 0.382,
#     'smash': 0.267
# }
UMG = pd.unique(score_marker_genes(high_markers,cosg_marker_genes,selected_genes, methods_importance, p=0.95))
# Out:
# total genes: 25127
# selected genes: 23870

# %%
len(UMG)
# Out:
# 23870

# %%
X_dense = adata.X
if hasattr(X_dense, 'toarray'):
    X_dense = X_dense.toarray()

exp_data = pd.DataFrame(
    X_dense.T,
    index=adata.var_names,
    columns=adata.obs_names
)

exp_data = exp_data.loc[UMG]

ccdata = sc.AnnData(X=exp_data.values.T)
ccdata.var_names = exp_data.index
ccdata.obs_names = exp_data.columns
ccdata.obs["cluster"] = adata.obs["cluster"]
print("\nReconstructed data from marker genes:")
print(ccdata)
# Out:
# Reconstructed data from marker genes:
# AnnData object with n_obs × n_vars = 7143 × 23870
#     obs: 'cluster'

# %%
if "X_pca" not in ccdata.obsm and "neighbors" not in ccdata.uns:
  sc.pp.pca(ccdata, n_comps=50)
  sc.pp.neighbors(ccdata, n_pcs=50)
cluster_with_louvain(ccdata, epochs=1, resolution=0.04)
# Out:
# ========================== Clustering With Louvain =================================
#
#
# Clustering epoch 1 ------------------
# Adjusted Rand Index (ARI): 0.7163
# Normalized Mutual Information (NMI): 0.6716
# Silhouette Score: 0.4570
# [0.45700336]
